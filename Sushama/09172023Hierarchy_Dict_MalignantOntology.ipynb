# %% [markdown]
# # Medical Name Entity Recognition
# 1. I want you to apply Natural Language tools to the unstrutured medical data and provide some clean outputs.
# For example:
# **Input:** Itching on the whole body might be a symptom of an underlying illness, such as liver disease, kidney disease, anemia, diabetes, thyroid problems and certain cancers. Nerve disorders. Examples include multiple sclerosis, pinched nerves and shingles (herpes zoster). Psychiatric conditions.
#
# **Output:** Itching, illness, liver disease, kidney disease, anemia, diabetes, thyroid, cancer, Nerve disorders, sclerosis, pinched nerves, shingles, herpes zoster, Psychiatric conditions.
#
# 2. This is an interesting thing and I don't think much diffcult. You can use NLP techniques like sentence detection, word detection, stop-word removal, etc to clean the data and then you can use the trained Medical Name entity recognition algorithms to find medical concepts.
#
# 3. These library can be explored for NLP tasks. Some of the popular NLP libraries for data cleaning include:
#
# NLTK (Natural Language Toolkit): NLTK is a comprehensive library for NLP tasks, including data cleaning, tokenization, stemming, lemmatization, part-of-speech tagging, and more.
#
# spaCy: spaCy is a fast and efficient NLP library that provides functionalities for tokenization, named entity recognition, and part-of-speech tagging, which can be useful for data cleaning.
#
# TextBlob: TextBlob is built on top of NLTK and provides a simplified interface for common NLP tasks, including text cleaning and sentiment analysis.
#
# gensim: While gensim is primarily known for topic modeling, it also offers tools for data preprocessing, such as text cleaning and word tokenization.
#
# BeautifulSoup: BeautifulSoup is not an NLP library per se, but it is a widely used library for parsing and extracting data from HTML and XML documents, which can be helpful when dealing with web text data.
#
# regex (re module): Python's built-in re module provides support for regular expressions, which are powerful tools for pattern matching and text cleaning.
#
# 4. For medical name entity recognition try to explore this link --> https://paperswithcode.com/task/medical-named-entity-recognition

# %%
import sqlite3

# %%
conn = sqlite3.connect("hierarchyMedicalConcepts.db")
cursor = conn.cursor()
# drop the table first and only then create
dropQuery= "DROP TABLE IF EXISTS hierarchyMedicalConcepts"
cursor.execute(dropQuery)
cursor.execute("""
    CREATE TABLE IF NOT EXISTS hierarchyMedicalConcepts(
        classDetailsId NVARCHAR(160),
        prefLabelParent NVARCHAR(160),
        distance1ID NVARCHAR(160) DEFAULT NULL,
        prefLabel1 NVARCHAR(160) DEFAULT NULL,
        distance2ID NVARCHAR(160) DEFAULT NULL,
        prefLabel2 NVARCHAR(160) DEFAULT NULL,
        distance3ID NVARCHAR(160) DEFAULT NULL,
        prefLabel3 NVARCHAR(160) DEFAULT NULL,
        distance4ID NVARCHAR(160) DEFAULT NULL,
        prefLabel4 NVARCHAR(160) DEFAULT NULL,
        distance5ID NVARCHAR(160) DEFAULT NULL,
        prefLabel5 NVARCHAR(160) DEFAULT NULL
    )
""")

# %%
displayAllQuery="PRAGMA table_info (hierarchyMedicalConcepts)"#"Select * from hierarchyMedicalConcepts"
cursor.execute(displayAllQuery)
results = cursor.fetchall()
print(results)
#for row in results:
 # display += f"classDetailsId: {row[0]}, distance1: {row[1]}, distance2: {row[2]}, distance3: {row[3]}, distance4:{row[4]}, distance5:{row[5]}"
# Out:
# [(0, 'classDetailsId', 'NVARCHAR(160)', 0, None, 0), (1, 'prefLabelParent', 'NVARCHAR(160)', 0, None, 0), (2, 'distance1ID', 'NVARCHAR(160)', 0, 'NULL', 0), (3, 'prefLabel1', 'NVARCHAR(160)', 0, 'NULL', 0), (4, 'distance2ID', 'NVARCHAR(160)', 0, 'NULL', 0), (5, 'prefLabel2', 'NVARCHAR(160)', 0, 'NULL', 0), (6, 'distance3ID', 'NVARCHAR(160)', 0, 'NULL', 0), (7, 'prefLabel3', 'NVARCHAR(160)', 0, 'NULL', 0), (8, 'distance4ID', 'NVARCHAR(160)', 0, 'NULL', 0), (9, 'prefLabel4', 'NVARCHAR(160)', 0, 'NULL', 0), (10, 'distance5ID', 'NVARCHAR(160)', 0, 'NULL', 0), (11, 'prefLabel5', 'NVARCHAR(160)', 0, 'NULL', 0)]

# %%
# Code here

# %% [markdown]
# # NESTED Dictionary creation for Bioportal Onotologies Generated data about Hierarchies.
#
# **Example Input:**
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/G-A425
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G-A200
# 			prefLabel: Positive
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G-A000
# 			prefLabel: Severity of illness, NOS
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G
# 			prefLabel: GENERAL LINKAGE/MODIFIERS
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 3
#
# **Example output in Nested Dictionary Form:**
# hierarchies = {
#     1: {
#         'hiearachy_1': 'Positive',
#         'hiearachy_2': 'Severity of illness, NOS',
#         'hiearachy_3': 'GENERAL LINKAGE/MODIFIERS'
#         'match_type': 'PREF'
#     },
#     2: {
#         'hiearachy_1': 'Positive',
#         'hiearachy_2': 'Severity of illness',
#         'hiearachy_3': 'GENERAL LINKAGE/MODIFIERS'
#         'match_type': 'Synon'
#     }
# }
#
# Things to consider:
# 1. Data should be in English language, translate or remove any content out of english.
# 2. Try to remove repetatives.
# 3. Python dictionary default size may exceed. Try using json format and create file instead.

# %%
import urllib.request, urllib.error, urllib.parse
import json
import os
#from typing import None
from pprint import pprint

REST_URL = "http://data.bioontology.org"
API_KEY = "396993d0-4ce2-4123-93de-214e9b9ebcf2"
concepts_list=['Malignant ontology']#['Orphanet']#['severe acute respiratory syndrome','joint']

def get_json(url):
    opener = urllib.request.build_opener()
    opener.addheaders = [('Authorization', 'apikey token=' + API_KEY)]
    return json.loads(opener.open(url).read())

def print_annotations(annotations, get_class=True):
    for result in annotations:
        class_details = result["annotatedClass"]
        if get_class:
            try:
                class_details = get_json(result["annotatedClass"]["links"]["self"])
                classDetailsId=class_details["@id"]
                prefLabelParent=str(class_details["prefLabel"])
            except urllib.error.HTTPError:
                print(f"Error retrieving {result['annotatedClass']['@id']}")
                continue
        print("Class details")
        print("\tid: " + class_details["@id"])
        print("\tprefLabel: " + str(class_details["prefLabel"]))
        print("\tontology: " + class_details["links"]["ontology"])

        print("Annotation details")
        for annotation in result["annotations"]:
            print("\tfrom: " + str(annotation["from"]))
            print("\tto: " + str(annotation["to"]))
            print("\tmatch type: " + annotation["matchType"])

        if result["hierarchy"]:
            print("\n\tHierarchy annotations")
            for annotation in result["hierarchy"]:
                try:
                    class_details = get_json(annotation["annotatedClass"]["links"]["self"])
                except urllib.error.HTTPError:
                    print(f"Error retrieving {annotation['annotatedClass']['@id']}")
                    continue
                pref_label = class_details["prefLabel"] or "no label"
                print("\t\tClass details")
                print("\t\t\tid: " + class_details["@id"])
                print("\t\t\tprefLabel: " + str(class_details["prefLabel"]))
                print("\t\t\tontology: " + class_details["links"]["ontology"])
                print("\t\t\tdistance from originally annotated class: " + str(annotation["distance"]))

                if str(annotation["distance"])=="1":
                  prefLabel1=pref_label
                  distance1ID=class_details["@id"]
                  # setting initial value to NULL for rest Hierarchies
                  prefLabel2 = None
                  distance2ID= None
                  prefLabel3=None
                  distance3ID=None
                  prefLabel4=None
                  distance4ID=None
                  prefLabel5=None
                  distance5ID=None
                  pass
                elif str(annotation["distance"])=="2":
                  prefLabel2=pref_label
                  print("prefLabel2 is: ", prefLabel2)
                  distance2ID=class_details["@id"]
                  print("distance2ID is: ",distance2ID)
                  pass
                elif str(annotation["distance"])=="3":
                  prefLabel3=pref_label
                  distance3ID=class_details["@id"]
                  pass
                elif str(annotation["distance"])=="4":
                  prefLabel4=pref_label
                  distance4ID=class_details["@id"]
                  pass
                elif str(annotation["distance"])=="5":
                  prefLabel5=pref_label
                  distance5ID=class_details["@id"]
                  pass

            insertQuery="INSERT INTO hierarchyMedicalConcepts (classDetailsId,prefLabelParent,prefLabel1,distance1ID,prefLabel2,distance2ID,prefLabel3,distance3ID,prefLabel4,distance4ID,prefLabel5,distance5ID) VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?,?) "
            conn.execute(insertQuery,(classDetailsId,prefLabelParent,prefLabel1,distance1ID,prefLabel2,distance2ID,prefLabel3,distance3ID,prefLabel4,distance4ID,prefLabel5,distance5ID))

        print("\n\n")

for i in concepts_list:
 text_to_annotate = i

# Annotate using the provided text
 annotations = get_json(REST_URL + "/annotator?text=" + urllib.parse.quote(text_to_annotate))

# Print out annotation details
 print_annotations(annotations)

# Annotate with hierarchy information
 annotations = get_json(REST_URL + "/annotator?max_level=5&text=" + urllib.parse.quote(text_to_annotate))
 print_annotations(annotations)

# Annotate with prefLabel, synonym, definition returned
 annotations = get_json(REST_URL + "/annotator?include=prefLabel,synonym,definition&text=" + urllib.parse.quote(text_to_annotate))
 print_annotations(annotations, False)
# Out:
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#C0205282
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/21594007
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/G-A425
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#20467
# 	prefLabel: 20467
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: SYN
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#Malignant
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/CSEO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://radlex.org/RID/RID15655
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/RADLEX
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.co-ode.org/ontologies/galen#malignant
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/GALEN
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/RCD/X78wJ
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/RCD
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Malignant
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/TCO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C14143
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/NCIT_C14143
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/PREMEDONTO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0006851
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/CCONT
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0006851
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/EFO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0006851
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/HSPO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: https://i2insights.org/index/integration-and-implementation-sciences-vocabulary#ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/I2SV
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://uri.neuinfo.org/nif/nifstd/birnlex_2339
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/NIFSTD
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/QUDT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEARP
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C21270
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEARP
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00741
# 	prefLabel: Semantic network
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/SIO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/BIOMO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEARP
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#ontology
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/EDDA_PT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BRO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BRO_ACRONYM
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/REGN_BRO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/NEMO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/DINTO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://edamontology.org/data_0582
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/EDAM
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://edamontology.org/data_0582
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/ITO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://edamontology.org/data_0582
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/SWO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/projects/ontologies/birnlex#birnlex_2339
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BIRNLEX
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://omv.ontoware.org/2005/05/ontology#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/OMV
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://omv.ontoware.org/2005/05/ontology#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BP-METADATA
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.cvrgrid.org/files/ECGOntologyv1.owl#ECG_000000073
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/ECG
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://edamontology.org/topic_0089
# 	prefLabel: Ontology and terminology
# 	ontology: https://data.bioontology.org/ontologies/BMT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://edamontology.org/topic_0089
# 	prefLabel: Ontology and terminology
# 	ontology: https://data.bioontology.org/ontologies/EDAM
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://edamontology.org/topic_0089
# 	prefLabel: Ontology and terminology
# 	ontology: https://data.bioontology.org/ontologies/BERO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://edamontology.org/topic_0089
# 	prefLabel: Ontology and terminology
# 	ontology: https://data.bioontology.org/ontologies/ITO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/GSSO_009995
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/GSSO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://protege.stanford.edu/ontologies/metadata/BioPortalMetadata.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BP-METADATA
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: file:/srv/ncbo/repository/COGAT/8/cogat.owl#trm_51838baad343e
# 	prefLabel: semantic network
# 	ontology: https://data.bioontology.org/ontologies/COGAT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://cui.unige.ch/isi/onto/tok/TOK.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/TOK
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.jp/bio/4/id/200906024075521203
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/IOBC
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#C0205282
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://sbmi.uth.tmc.edu/ontology/ochv#UMLS_Concept
# 			prefLabel: UMLS_Concept
# 			ontology: https://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2004/02/skos/core#Concept
# 			prefLabel: Concept
# 			ontology: https://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 2
# prefLabel2 is:  Concept
# distance2ID is:  http://www.w3.org/2004/02/skos/core#Concept
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/21594007
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/106234000
# 			prefLabel: General adjectival modifier
# 			ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/255297006
# 			prefLabel: Behavior descriptors
# 			ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/272099008
# 			prefLabel: Descriptor
# 			ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 2
# prefLabel2 is:  Descriptor
# distance2ID is:  http://purl.bioontology.org/ontology/SNOMEDCT/272099008
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/362981000
# 			prefLabel: Qualifier value
# 			ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/G-A425
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G-A200
# 			prefLabel: Positive
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G-A000
# 			prefLabel: Severity of illness, NOS
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 2
# prefLabel2 is:  Severity of illness, NOS
# distance2ID is:  http://purl.bioontology.org/ontology/SNMI/G-A000
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G
# 			prefLabel: GENERAL LINKAGE/MODIFIERS
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#20467
# 	prefLabel: 20467
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://sbmi.uth.tmc.edu/ontology/ochv#CHV_Concept
# 			prefLabel: CHV_Concept
# 			ontology: https://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2004/02/skos/core#Concept
# 			prefLabel: Concept
# 			ontology: https://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 2
# prefLabel2 is:  Concept
# distance2ID is:  http://www.w3.org/2004/02/skos/core#Concept
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#Malignant
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/CSEO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.ifomis.org/snap#Quality
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.ifomis.org/snap#SpecificallyDependentContinuant
# 			prefLabel: specifically_dependent_continuant
# 			ontology: https://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 2
# prefLabel2 is:  specifically_dependent_continuant
# distance2ID is:  http://www.ifomis.org/snap#SpecificallyDependentContinuant
# 		Class details
# 			id: http://www.ifomis.org/snap#DependentContinuant
# 			prefLabel: dependent_continuant
# 			ontology: https://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ifomis.org/snap#Continuant
# 			prefLabel: continuant
# 			ontology: https://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1#Entity
# 			prefLabel: entity
# 			ontology: https://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://radlex.org/RID/RID15655
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/RADLEX
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://radlex.org/RID/RID5675
# 			prefLabel: aggressiveness descriptor
# 			ontology: https://data.bioontology.org/ontologies/RADLEX
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://radlex.org/RID/RID6
# 			prefLabel: RadLex descriptor
# 			ontology: https://data.bioontology.org/ontologies/RADLEX
# 			distance from originally annotated class: 2
# prefLabel2 is:  RadLex descriptor
# distance2ID is:  http://radlex.org/RID/RID6
# 		Class details
# 			id: http://radlex.org/RID/RID1
# 			prefLabel: RadLex entity
# 			ontology: https://data.bioontology.org/ontologies/RADLEX
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://radlex.org/RID/RID0
# 			prefLabel: RadLex ontology entity
# 			ontology: https://data.bioontology.org/ontologies/RADLEX
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://www.co-ode.org/ontologies/galen#malignant
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/GALEN
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#MalignancyState
# 			prefLabel: MalignancyState
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#DiseaseState
# 			prefLabel: DiseaseState
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 2
# prefLabel2 is:  DiseaseState
# distance2ID is:  http://www.co-ode.org/ontologies/galen#DiseaseState
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#ProcessState
# 			prefLabel: ProcessState
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#State
# 			prefLabel: State
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#SymbolicValueType
# 			prefLabel: SymbolicValueType
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 5
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#StateOrQuantity
# 			prefLabel: StateOrQuantity
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/RCD/X78wJ
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/RCD
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/X78vs
# 			prefLabel: Behaviour descriptors
# 			ontology: https://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/XM0Dh
# 			prefLabel: Descriptors
# 			ontology: https://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 2
# prefLabel2 is:  Descriptors
# distance2ID is:  http://purl.bioontology.org/ontology/RCD/XM0Dh
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/X78tJ
# 			prefLabel: Additional values
# 			ontology: https://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/.....
# 			prefLabel: Read thesaurus
# 			ontology: https://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Malignant
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/TCO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Cytologic_Test
# 			prefLabel: Cytologic_Test
# 			ontology: https://data.bioontology.org/ontologies/TCO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Biopsy_of_Thyroid_Gland
# 			prefLabel: Biopsy_of_Thyroid_Gland
# 			ontology: https://data.bioontology.org/ontologies/TCO
# 			distance from originally annotated class: 2
# prefLabel2 is:  Biopsy_of_Thyroid_Gland
# distance2ID is:  http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Biopsy_of_Thyroid_Gland
# 		Class details
# 			id: http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Investigation
# 			prefLabel: Investigation
# 			ontology: https://data.bioontology.org/ontologies/TCO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Clinical_Aspects
# 			prefLabel: Clinical_Aspects
# 			ontology: https://data.bioontology.org/ontologies/TCO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Thyroid_Cancer
# 			prefLabel: Thyroid_Cancer
# 			ontology: https://data.bioontology.org/ontologies/TCO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C14143
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C28099
# 			prefLabel: Disease Morphology Qualifier
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C27992
# 			prefLabel: Disease Qualifier
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 2
# prefLabel2 is:  Disease Qualifier
# distance2ID is:  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C27992
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C41009
# 			prefLabel: Qualifier
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20189
# 			prefLabel: Property or Attribute
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/NCIT_C14143
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/PREMEDONTO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/NCIT_C28099
# 			prefLabel: Disease Morphology Qualifier
# 			ontology: https://data.bioontology.org/ontologies/PREMEDONTO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/NCIT_C27992
# 			prefLabel: Disease Qualifier
# 			ontology: https://data.bioontology.org/ontologies/PREMEDONTO
# 			distance from originally annotated class: 2
# prefLabel2 is:  Disease Qualifier
# distance2ID is:  http://purl.obolibrary.org/obo/NCIT_C27992
# 		Class details
# 			id: http://purl.obolibrary.org/obo/NCIT_C41009
# 			prefLabel: Qualifier
# 			ontology: https://data.bioontology.org/ontologies/PREMEDONTO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/NCIT_C20189
# 			prefLabel: Property or Attribute
# 			ontology: https://data.bioontology.org/ontologies/PREMEDONTO
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0006851
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/CCONT
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.ebi.ac.uk/efo/EFO_0010569
# 			prefLabel: clinical modifier
# 			ontology: https://data.bioontology.org/ontologies/CCONT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000019
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/CCONT
# 			distance from originally annotated class: 2
# prefLabel2 is:  quality
# distance2ID is:  http://purl.obolibrary.org/obo/BFO_0000019
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000020
# 			prefLabel: material property
# 			ontology: https://data.bioontology.org/ontologies/CCONT
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ebi.ac.uk/efo/EFO_0000001
# 			prefLabel: experimental factor
# 			ontology: https://data.bioontology.org/ontologies/CCONT
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0006851
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/EFO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.ebi.ac.uk/efo/EFO_0010569
# 			prefLabel: clinical modifier
# 			ontology: https://data.bioontology.org/ontologies/EFO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000019
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/EFO
# 			distance from originally annotated class: 2
# prefLabel2 is:  quality
# distance2ID is:  http://purl.obolibrary.org/obo/BFO_0000019
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000020
# 			prefLabel: material property
# 			ontology: https://data.bioontology.org/ontologies/EFO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ebi.ac.uk/efo/EFO_0000001
# 			prefLabel: experimental factor
# 			ontology: https://data.bioontology.org/ontologies/EFO
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0006851
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/HSPO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.ebi.ac.uk/efo/EFO_0010569
# 			prefLabel: clinical modifier
# 			ontology: https://data.bioontology.org/ontologies/HSPO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000019
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/HSPO
# 			distance from originally annotated class: 2
# prefLabel2 is:  quality
# distance2ID is:  http://purl.obolibrary.org/obo/BFO_0000019
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000020
# 			prefLabel: material property
# 			ontology: https://data.bioontology.org/ontologies/HSPO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ebi.ac.uk/efo/EFO_0000001
# 			prefLabel: experimental factor
# 			ontology: https://data.bioontology.org/ontologies/HSPO
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: https://i2insights.org/index/integration-and-implementation-sciences-vocabulary#ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/I2SV
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://uri.neuinfo.org/nif/nifstd/birnlex_2339
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/NIFSTD
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://uri.neuinfo.org/nif/nifstd/birnlex_2334
# 			prefLabel: Structured knowledge resource
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://uri.neuinfo.org/nif/nifstd/birnlex_2334_1
# 			prefLabel: Structured knowledge resource
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://uri.neuinfo.org/nif/nifstd/nlx_res_20090102
# 			prefLabel: Data resource
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 2
# prefLabel2 is:  Data resource
# distance2ID is:  http://uri.neuinfo.org/nif/nifstd/nlx_res_20090102
# 		Class details
# 			id: http://uri.neuinfo.org/nif/nifstd/nlx_res_20090101
# 			prefLabel: Resource
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000031
# 			prefLabel: generically dependent continuant
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000002
# 			prefLabel: continuant
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://datashapes.org/graphql#Schema
# 			prefLabel: GraphQL Schema
# 			ontology: https://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2000/01/rdf-schema#Resource
# 			prefLabel: Resource
# 			ontology: https://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 2
# prefLabel2 is:  Resource
# distance2ID is:  http://www.w3.org/2000/01/rdf-schema#Resource
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/QUDT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://datashapes.org/graphql#Schema
# 			prefLabel: GraphQL Schema
# 			ontology: https://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2000/01/rdf-schema#Resource
# 			prefLabel: Resource
# 			ontology: https://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 2
# prefLabel2 is:  Resource
# distance2ID is:  http://www.w3.org/2000/01/rdf-schema#Resource
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://datashapes.org/graphql#Schema
# 			prefLabel: GraphQL Schema
# 			ontology: https://data.bioontology.org/ontologies/HASCO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2000/01/rdf-schema#Resource
# 			prefLabel: Resource
# 			ontology: https://data.bioontology.org/ontologies/HASCO
# 			distance from originally annotated class: 2
# prefLabel2 is:  Resource
# distance2ID is:  http://www.w3.org/2000/01/rdf-schema#Resource
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEARP
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://datashapes.org/graphql#Schema
# 			prefLabel: GraphQL Schema
# 			ontology: https://data.bioontology.org/ontologies/HHEARP
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2000/01/rdf-schema#Resource
# 			prefLabel: Resource
# 			ontology: https://data.bioontology.org/ontologies/HHEARP
# 			distance from originally annotated class: 2
# prefLabel2 is:  Resource
# distance2ID is:  http://www.w3.org/2000/01/rdf-schema#Resource
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://datashapes.org/graphql#Schema
# 			prefLabel: GraphQL Schema
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2000/01/rdf-schema#Resource
# 			prefLabel: Resource
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 2
# prefLabel2 is:  Resource
# distance2ID is:  http://www.w3.org/2000/01/rdf-schema#Resource
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C21270
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C142730
# 			prefLabel: Terminology
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C16048
# 			prefLabel: Information Resource
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 2
# prefLabel2 is:  Information Resource
# distance2ID is:  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C16048
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20865
# 			prefLabel: Information and Media
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20181
# 			prefLabel: Conceptual Entity
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEARP
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00741
# 	prefLabel: Semantic network
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00001
# 			prefLabel: Cognitive Entity
# 			ontology: https://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://hadatac.org/ont/chear#NeurocognitiveAssessent
# 			prefLabel: NeurocognitiveAssessent
# 			ontology: https://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 2
# prefLabel2 is:  NeurocognitiveAssessent
# distance2ID is:  http://hadatac.org/ont/chear#NeurocognitiveAssessent
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/SIO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000621
# 			prefLabel: formal specification
# 			ontology: https://data.bioontology.org/ontologies/SIO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000315
# 			prefLabel: functional specification
# 			ontology: https://data.bioontology.org/ontologies/SIO
# 			distance from originally annotated class: 2
# prefLabel2 is:  functional specification
# distance2ID is:  http://semanticscience.org/resource/SIO_000315
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000090
# 			prefLabel: specification
# 			ontology: https://data.bioontology.org/ontologies/SIO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000136
# 			prefLabel: description
# 			ontology: https://data.bioontology.org/ontologies/SIO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000078
# 			prefLabel: language entity
# 			ontology: https://data.bioontology.org/ontologies/SIO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000621
# 			prefLabel: formal specification
# 			ontology: https://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000315
# 			prefLabel: functional specification
# 			ontology: https://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 2
# prefLabel2 is:  functional specification
# distance2ID is:  http://semanticscience.org/resource/SIO_000315
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000090
# 			prefLabel: specification
# 			ontology: https://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000136
# 			prefLabel: description
# 			ontology: https://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000078
# 			prefLabel: language entity
# 			ontology: https://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000621
# 			prefLabel: formal specification
# 			ontology: https://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000315
# 			prefLabel: functional specification
# 			ontology: https://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 2
# prefLabel2 is:  functional specification
# distance2ID is:  http://semanticscience.org/resource/SIO_000315
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000090
# 			prefLabel: specification
# 			ontology: https://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000136
# 			prefLabel: description
# 			ontology: https://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000078
# 			prefLabel: language entity
# 			ontology: https://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/BIOMO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000621
# 			prefLabel: formal specification
# 			ontology: https://data.bioontology.org/ontologies/BIOMO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000315
# 			prefLabel: functional specification
# 			ontology: https://data.bioontology.org/ontologies/BIOMO
# 			distance from originally annotated class: 2
# prefLabel2 is:  functional specification
# distance2ID is:  http://semanticscience.org/resource/SIO_000315
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000090
# 			prefLabel: specification
# 			ontology: https://data.bioontology.org/ontologies/BIOMO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000136
# 			prefLabel: description
# 			ontology: https://data.bioontology.org/ontologies/BIOMO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000078
# 			prefLabel: language entity
# 			ontology: https://data.bioontology.org/ontologies/BIOMO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000621
# 			prefLabel: formal specification
# 			ontology: https://data.bioontology.org/ontologies/HASCO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000315
# 			prefLabel: functional specification
# 			ontology: https://data.bioontology.org/ontologies/HASCO
# 			distance from originally annotated class: 2
# prefLabel2 is:  functional specification
# distance2ID is:  http://semanticscience.org/resource/SIO_000315
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000090
# 			prefLabel: specification
# 			ontology: https://data.bioontology.org/ontologies/HASCO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000136
# 			prefLabel: description
# 			ontology: https://data.bioontology.org/ontologies/HASCO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000078
# 			prefLabel: language entity
# 			ontology: https://data.bioontology.org/ontologies/HASCO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEARP
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000621
# 			prefLabel: formal specification
# 			ontology: https://data.bioontology.org/ontologies/HHEARP
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000315
# 			prefLabel: functional specification
# 			ontology: https://data.bioontology.org/ontologies/HHEARP
# 			distance from originally annotated class: 2
# prefLabel2 is:  functional specification
# distance2ID is:  http://semanticscience.org/resource/SIO_000315
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000090
# 			prefLabel: specification
# 			ontology: https://data.bioontology.org/ontologies/HHEARP
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000136
# 			prefLabel: description
# 			ontology: https://data.bioontology.org/ontologies/HHEARP
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000078
# 			prefLabel: language entity
# 			ontology: https://data.bioontology.org/ontologies/HHEARP
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000621
# 			prefLabel: formal specification
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000315
# 			prefLabel: functional specification
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 2
# prefLabel2 is:  functional specification
# distance2ID is:  http://semanticscience.org/resource/SIO_000315
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000090
# 			prefLabel: specification
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000136
# 			prefLabel: description
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000078
# 			prefLabel: language entity
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#ontology
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/EDDA_PT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#thesaurus
# 			prefLabel: thesaurus
# 			ontology: https://data.bioontology.org/ontologies/EDDA_PT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#taxonomy
# 			prefLabel: taxonomy
# 			ontology: https://data.bioontology.org/ontologies/EDDA_PT
# 			distance from originally annotated class: 2
# prefLabel2 is:  taxonomy
# distance2ID is:  http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#taxonomy
# 		Class details
# 			id: http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#terminology
# 			prefLabel: terminology
# 			ontology: https://data.bioontology.org/ontologies/EDDA_PT
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#publication_type
# 			prefLabel: publication type
# 			ontology: https://data.bioontology.org/ontologies/EDDA_PT
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BRO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Structured_Knowledge_Resource
# 			prefLabel: Structured Knowledge Resource
# 			ontology: https://data.bioontology.org/ontologies/BRO
# 			distance from originally annotated class: 1
# 		Class details
# ...
# 			distance from originally annotated class: 2
# prefLabel2 is:  Knowledge domain
# distance2ID is:  https://identifiers.org/ito:ITO_01680
# 		Class details
# 			id: https://identifiers.org/ito:Topic
# 			prefLabel: Topic
# 			ontology: https://data.bioontology.org/ontologies/ITO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/GSSO_009995
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/GSSO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MESH/D008678
# 			prefLabel: metaphysics
# 			ontology: https://data.bioontology.org/ontologies/GSSO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GSSO_003088
# 			prefLabel: basic philosophy
# 			ontology: https://data.bioontology.org/ontologies/GSSO
# 			distance from originally annotated class: 2
# prefLabel2 is:  basic philosophy
# distance2ID is:  http://purl.obolibrary.org/obo/GSSO_003088
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MESH/D010684
# 			prefLabel: philosophy
# 			ontology: https://data.bioontology.org/ontologies/GSSO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GSSO_002368
# 			prefLabel: basic humanities
# 			ontology: https://data.bioontology.org/ontologies/GSSO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GSSO_002346
# 			prefLabel: humanities
# 			ontology: https://data.bioontology.org/ontologies/GSSO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://protege.stanford.edu/ontologies/metadata/BioPortalMetadata.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BP-METADATA
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://protege.stanford.edu/ontologies/ChAO/changes.rdfs#AnnotatableThing
# 			prefLabel: AnnotatableThing
# 			ontology: https://data.bioontology.org/ontologies/BP-METADATA
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2000/01/rdf-schema#Resource
# 			prefLabel: Resource
# 			ontology: https://data.bioontology.org/ontologies/BP-METADATA
# 			distance from originally annotated class: 2
# prefLabel2 is:  Resource
# distance2ID is:  http://www.w3.org/2000/01/rdf-schema#Resource
#
#
#
# Class details
# 	id: file:/srv/ncbo/repository/COGAT/8/cogat.owl#trm_51838baad343e
# 	prefLabel: semantic network
# 	ontology: https://data.bioontology.org/ontologies/COGAT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://cui.unige.ch/isi/onto/tok/TOK.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/TOK
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://cui.unige.ch/isi/onto/tok/TOK.owl#TOK_Resource
# 			prefLabel: TOK_Resource
# 			ontology: https://data.bioontology.org/ontologies/TOK
# 			distance from originally annotated class: 1
#
#
#
# Class details
# 	id: http://purl.jp/bio/4/id/200906024075521203
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/IOBC
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.jp/bio/4/subject/BA01_cat
# 			prefLabel: Terms related to Documentation and information science
# 			ontology: https://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.jp/bio/4/subject/LS_ur_c/OWLClass_00000000000000000470
# 			prefLabel: Management science and system engineering
# 			ontology: https://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 2
# prefLabel2 is:  Management science and system engineering
# distance2ID is:  http://purl.jp/bio/4/subject/LS_ur_c/OWLClass_00000000000000000470
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#C0205282
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/21594007
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/G-A425
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#20467
# 	prefLabel: 20467
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: SYN
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#Malignant
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/CSEO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://radlex.org/RID/RID15655
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/RADLEX
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.co-ode.org/ontologies/galen#malignant
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/GALEN
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/RCD/X78wJ
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/RCD
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Malignant
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/TCO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C14143
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/NCIT_C14143
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/PREMEDONTO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0006851
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/CCONT
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0006851
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/EFO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0006851
# 	prefLabel: malignant
# 	ontology: https://data.bioontology.org/ontologies/HSPO
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
#
#
# Class details
# 	id: https://i2insights.org/index/integration-and-implementation-sciences-vocabulary#ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/I2SV
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://uri.neuinfo.org/nif/nifstd/birnlex_2339
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/NIFSTD
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/QUDT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEARP
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.w3.org/2002/07/owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C21270
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEARP
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://teamwork.topbraidlive.org/ontologyprojects#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00741
# 	prefLabel: Semantic network
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/SIO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/BIOMO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEARP
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_001391
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#ontology
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/EDDA_PT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BRO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BRO_ACRONYM
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/REGN_BRO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/NEMO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/DINTO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://edamontology.org/data_0582
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/EDAM
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://edamontology.org/data_0582
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/ITO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://edamontology.org/data_0582
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/SWO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioontology.org/projects/ontologies/birnlex#birnlex_2339
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BIRNLEX
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://omv.ontoware.org/2005/05/ontology#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/OMV
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://omv.ontoware.org/2005/05/ontology#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BP-METADATA
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.cvrgrid.org/files/ECGOntologyv1.owl#ECG_000000073
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/ECG
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://edamontology.org/topic_0089
# 	prefLabel: Ontology and terminology
# 	ontology: https://data.bioontology.org/ontologies/BMT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://edamontology.org/topic_0089
# 	prefLabel: Ontology and terminology
# 	ontology: https://data.bioontology.org/ontologies/EDAM
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://edamontology.org/topic_0089
# 	prefLabel: Ontology and terminology
# 	ontology: https://data.bioontology.org/ontologies/BERO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://edamontology.org/topic_0089
# 	prefLabel: Ontology and terminology
# 	ontology: https://data.bioontology.org/ontologies/ITO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/GSSO_009995
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/GSSO
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://protege.stanford.edu/ontologies/metadata/BioPortalMetadata.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/BP-METADATA
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: file:/srv/ncbo/repository/COGAT/8/cogat.owl#trm_51838baad343e
# 	prefLabel: semantic network
# 	ontology: https://data.bioontology.org/ontologies/COGAT
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: SYN
#
#
#
# Class details
# 	id: http://cui.unige.ch/isi/onto/tok/TOK.owl#Ontology
# 	prefLabel: Ontology
# 	ontology: https://data.bioontology.org/ontologies/TOK
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.jp/bio/4/id/200906024075521203
# 	prefLabel: ontology
# 	ontology: https://data.bioontology.org/ontologies/IOBC
# Annotation details
# 	from: 11
# 	to: 18
# 	match type: PREF

# %%
cursor.execute("SELECT * FROM hierarchyMedicalConcepts")

# %%
rows = cursor.fetchall()

# Print the results
for row in rows:
    print("\nhello",row)
# Out:
# hello ('http://sbmi.uth.tmc.edu/ontology/ochv#C0205282', 'malignant', 'http://sbmi.uth.tmc.edu/ontology/ochv#UMLS_Concept', 'UMLS_Concept', 'http://www.w3.org/2004/02/skos/core#Concept', 'Concept', None, None, None, None, None, None)
#
# hello ('http://purl.bioontology.org/ontology/SNOMEDCT/21594007', 'Malignant', 'http://purl.bioontology.org/ontology/SNOMEDCT/255297006', 'Behavior descriptors', 'http://purl.bioontology.org/ontology/SNOMEDCT/272099008', 'Descriptor', 'http://purl.bioontology.org/ontology/SNOMEDCT/362981000', 'Qualifier value', None, None, None, None)
#
# hello ('http://purl.bioontology.org/ontology/SNMI/G-A425', 'Malignant', 'http://purl.bioontology.org/ontology/SNMI/G-A200', 'Positive', 'http://purl.bioontology.org/ontology/SNMI/G-A000', 'Severity of illness, NOS', 'http://purl.bioontology.org/ontology/SNMI/G', 'GENERAL LINKAGE/MODIFIERS', None, None, None, None)
#
# hello ('http://sbmi.uth.tmc.edu/ontology/ochv#20467', '20467', 'http://sbmi.uth.tmc.edu/ontology/ochv#CHV_Concept', 'CHV_Concept', 'http://www.w3.org/2004/02/skos/core#Concept', 'Concept', None, None, None, None, None, None)
#
# hello ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#Malignant', 'Malignant', 'http://www.ifomis.org/snap#Quality', 'quality', 'http://www.ifomis.org/snap#SpecificallyDependentContinuant', 'specifically_dependent_continuant', 'http://www.ifomis.org/snap#DependentContinuant', 'dependent_continuant', 'http://www.ifomis.org/snap#Continuant', 'continuant', 'http://www.ifomis.org/bfo/1.1#Entity', 'entity')
#
# hello ('http://radlex.org/RID/RID15655', 'malignant', 'http://radlex.org/RID/RID5675', 'aggressiveness descriptor', 'http://radlex.org/RID/RID6', 'RadLex descriptor', 'http://radlex.org/RID/RID1', 'RadLex entity', 'http://radlex.org/RID/RID0', 'RadLex ontology entity', None, None)
#
# hello ('http://www.co-ode.org/ontologies/galen#malignant', 'malignant', 'http://www.co-ode.org/ontologies/galen#MalignancyState', 'MalignancyState', 'http://www.co-ode.org/ontologies/galen#DiseaseState', 'DiseaseState', 'http://www.co-ode.org/ontologies/galen#ProcessState', 'ProcessState', 'http://www.co-ode.org/ontologies/galen#State', 'State', 'http://www.co-ode.org/ontologies/galen#StateOrQuantity', 'StateOrQuantity')
#
# hello ('http://purl.bioontology.org/ontology/RCD/X78wJ', 'Malignant', 'http://purl.bioontology.org/ontology/RCD/X78vs', 'Behaviour descriptors', 'http://purl.bioontology.org/ontology/RCD/XM0Dh', 'Descriptors', 'http://purl.bioontology.org/ontology/RCD/X78tJ', 'Additional values', 'http://purl.bioontology.org/ontology/RCD/.....', 'Read thesaurus', None, None)
#
# hello ('http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Malignant', 'Malignant', 'http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Cytologic_Test', 'Cytologic_Test', 'http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Biopsy_of_Thyroid_Gland', 'Biopsy_of_Thyroid_Gland', 'http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Investigation', 'Investigation', 'http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Clinical_Aspects', 'Clinical_Aspects', 'http://www.semanticweb.org/hx-jta/ontologies/thyroid_cancer_ontology#Thyroid_Cancer', 'Thyroid_Cancer')
#
# hello ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C14143', 'Malignant', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C28099', 'Disease Morphology Qualifier', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C27992', 'Disease Qualifier', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C41009', 'Qualifier', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20189', 'Property or Attribute', None, None)
#
# hello ('http://purl.obolibrary.org/obo/NCIT_C14143', 'Malignant', 'http://purl.obolibrary.org/obo/NCIT_C28099', 'Disease Morphology Qualifier', 'http://purl.obolibrary.org/obo/NCIT_C27992', 'Disease Qualifier', 'http://purl.obolibrary.org/obo/NCIT_C41009', 'Qualifier', 'http://purl.obolibrary.org/obo/NCIT_C20189', 'Property or Attribute', None, None)
#
# hello ('http://www.ebi.ac.uk/efo/EFO_0006851', 'malignant', 'http://www.ebi.ac.uk/efo/EFO_0010569', 'clinical modifier', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'material property', 'http://www.ebi.ac.uk/efo/EFO_0000001', 'experimental factor', None, None)
#
# hello ('http://www.ebi.ac.uk/efo/EFO_0006851', 'malignant', 'http://www.ebi.ac.uk/efo/EFO_0010569', 'clinical modifier', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'material property', 'http://www.ebi.ac.uk/efo/EFO_0000001', 'experimental factor', None, None)
#
# hello ('http://www.ebi.ac.uk/efo/EFO_0006851', 'malignant', 'http://www.ebi.ac.uk/efo/EFO_0010569', 'clinical modifier', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'material property', 'http://www.ebi.ac.uk/efo/EFO_0000001', 'experimental factor', None, None)
#
# hello ('http://uri.neuinfo.org/nif/nifstd/birnlex_2339', 'Ontology', 'http://uri.neuinfo.org/nif/nifstd/birnlex_2334_1', 'Structured knowledge resource', 'http://uri.neuinfo.org/nif/nifstd/nlx_res_20090102', 'Data resource', 'http://uri.neuinfo.org/nif/nifstd/nlx_res_20090101', 'Resource', 'http://purl.obolibrary.org/obo/BFO_0000031', 'generically dependent continuant', 'http://purl.obolibrary.org/obo/BFO_0000002', 'continuant')
#
# hello ('http://www.w3.org/2002/07/owl#Ontology', 'Ontology', 'http://datashapes.org/graphql#Schema', 'GraphQL Schema', 'http://www.w3.org/2000/01/rdf-schema#Resource', 'Resource', None, None, None, None, None, None)
#
# hello ('http://www.w3.org/2002/07/owl#Ontology', 'Ontology', 'http://datashapes.org/graphql#Schema', 'GraphQL Schema', 'http://www.w3.org/2000/01/rdf-schema#Resource', 'Resource', None, None, None, None, None, None)
#
# hello ('http://www.w3.org/2002/07/owl#Ontology', 'Ontology', 'http://datashapes.org/graphql#Schema', 'GraphQL Schema', 'http://www.w3.org/2000/01/rdf-schema#Resource', 'Resource', None, None, None, None, None, None)
#
# hello ('http://www.w3.org/2002/07/owl#Ontology', 'Ontology', 'http://datashapes.org/graphql#Schema', 'GraphQL Schema', 'http://www.w3.org/2000/01/rdf-schema#Resource', 'Resource', None, None, None, None, None, None)
#
# hello ('http://www.w3.org/2002/07/owl#Ontology', 'Ontology', 'http://datashapes.org/graphql#Schema', 'GraphQL Schema', 'http://www.w3.org/2000/01/rdf-schema#Resource', 'Resource', None, None, None, None, None, None)
#
# hello ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C21270', 'Ontology', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C142730', 'Terminology', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C16048', 'Information Resource', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20865', 'Information and Media', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20181', 'Conceptual Entity', None, None)
#
# hello ('http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00741', 'Semantic network', 'http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00001', 'Cognitive Entity', 'http://hadatac.org/ont/chear#NeurocognitiveAssessent', 'NeurocognitiveAssessent', None, None, None, None, None, None)
#
# hello ('http://semanticscience.org/resource/SIO_001391', 'ontology', 'http://semanticscience.org/resource/SIO_000621', 'formal specification', 'http://semanticscience.org/resource/SIO_000315', 'functional specification', 'http://semanticscience.org/resource/SIO_000090', 'specification', 'http://semanticscience.org/resource/SIO_000136', 'description', 'http://semanticscience.org/resource/SIO_000078', 'language entity')
#
# hello ('http://semanticscience.org/resource/SIO_001391', 'ontology', 'http://semanticscience.org/resource/SIO_000621', 'formal specification', 'http://semanticscience.org/resource/SIO_000315', 'functional specification', 'http://semanticscience.org/resource/SIO_000090', 'specification', 'http://semanticscience.org/resource/SIO_000136', 'description', 'http://semanticscience.org/resource/SIO_000078', 'language entity')
#
# hello ('http://semanticscience.org/resource/SIO_001391', 'ontology', 'http://semanticscience.org/resource/SIO_000621', 'formal specification', 'http://semanticscience.org/resource/SIO_000315', 'functional specification', 'http://semanticscience.org/resource/SIO_000090', 'specification', 'http://semanticscience.org/resource/SIO_000136', 'description', 'http://semanticscience.org/resource/SIO_000078', 'language entity')
#
# hello ('http://semanticscience.org/resource/SIO_001391', 'ontology', 'http://semanticscience.org/resource/SIO_000621', 'formal specification', 'http://semanticscience.org/resource/SIO_000315', 'functional specification', 'http://semanticscience.org/resource/SIO_000090', 'specification', 'http://semanticscience.org/resource/SIO_000136', 'description', 'http://semanticscience.org/resource/SIO_000078', 'language entity')
#
# hello ('http://semanticscience.org/resource/SIO_001391', 'ontology', 'http://semanticscience.org/resource/SIO_000621', 'formal specification', 'http://semanticscience.org/resource/SIO_000315', 'functional specification', 'http://semanticscience.org/resource/SIO_000090', 'specification', 'http://semanticscience.org/resource/SIO_000136', 'description', 'http://semanticscience.org/resource/SIO_000078', 'language entity')
#
# hello ('http://semanticscience.org/resource/SIO_001391', 'ontology', 'http://semanticscience.org/resource/SIO_000621', 'formal specification', 'http://semanticscience.org/resource/SIO_000315', 'functional specification', 'http://semanticscience.org/resource/SIO_000090', 'specification', 'http://semanticscience.org/resource/SIO_000136', 'description', 'http://semanticscience.org/resource/SIO_000078', 'language entity')
#
# hello ('http://semanticscience.org/resource/SIO_001391', 'ontology', 'http://semanticscience.org/resource/SIO_000621', 'formal specification', 'http://semanticscience.org/resource/SIO_000315', 'functional specification', 'http://semanticscience.org/resource/SIO_000090', 'specification', 'http://semanticscience.org/resource/SIO_000136', 'description', 'http://semanticscience.org/resource/SIO_000078', 'language entity')
#
# hello ('http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#ontology', 'ontology', 'http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#thesaurus', 'thesaurus', 'http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#taxonomy', 'taxonomy', 'http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#terminology', 'terminology', 'http://ontologies.dbmi.pitt.edu/edda/PublicationType.owl#publication_type', 'publication type', None, None)
#
# hello ('http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology', 'Ontology', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Structured_Knowledge_Resource', 'Structured Knowledge Resource', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Information_Resource', 'Information Resource', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Resource', 'Resource', None, None, None, None)
#
# hello ('http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology', 'Ontology', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Structured_Knowledge_Resource', 'Structured Knowledge Resource', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Information_Resource', 'Information Resource', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Resource', 'Resource', None, None, None, None)
#
# hello ('http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology', 'Ontology', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Structured_Knowledge_Resource', 'Structured Knowledge Resource', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Information_Resource', 'Information Resource', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Resource', 'Resource', None, None, None, None)
#
# hello ('http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology', 'ontology', 'http://ontology.neuinfo.org/NIF/DigitalEntities/NIF-Resource.owl#nlx_res_20090102', 'data_resource', 'http://purl.obolibrary.org/obo/IAO_0000030', 'information_content_entity', 'http://www.ifomis.org/bfo/1.1/snap#GenericallyDependentContinuant', 'generically_dependent_continuant', 'http://www.ifomis.org/bfo/1.1/snap#DependentContinuant', 'dependent_continuant', 'http://www.ifomis.org/bfo/1.1/snap#Continuant', 'continuant')
#
# hello ('http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Ontology', 'Ontology', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Structured_Knowledge_Resource', 'Structured Knowledge Resource', 'http://bioontology.org/ontologies/BiomedicalResourceOntology.owl#Information_Resource', 'Information Resource', None, None, None, None, None, None)
#
# hello ('http://edamontology.org/data_0582', 'Ontology', 'http://edamontology.org/data_2353', 'Ontology data', 'http://edamontology.org/data_0006', 'Data', None, None, None, None, None, None)
#
# hello ('http://edamontology.org/data_0582', 'Ontology', 'http://edamontology.org/data_2353', 'Ontology data', 'http://edamontology.org/data_0006', 'Data', 'https://identifiers.org/ito:Data', 'Data', None, None, None, None)
#
# hello ('http://edamontology.org/data_0582', 'Ontology', 'http://purl.obolibrary.org/obo/IAO_0000027', 'data item', 'http://purl.obolibrary.org/obo/IAO_0000030', 'information content entity', 'http://purl.obolibrary.org/obo/BFO_0000031', 'generically dependent continuant', 'http://purl.obolibrary.org/obo/BFO_0000002', 'continuant', 'http://purl.obolibrary.org/obo/BFO_0000001', 'entity')
#
# hello ('http://bioontology.org/projects/ontologies/birnlex#birnlex_2339', 'Ontology', 'http://bioontology.org/projects/ontologies/birnlex#birnlex_2334', 'Structured knowledge resource', 'http://bioontology.org/projects/ontologies/birnlex#birnlex_11006', 'Data set', 'http://bioontology.org/projects/ontologies/birnlex#birnlex_11002', 'Data object', 'http://bioontology.org/projects/ontologies/birnlex#birnlex_11001', 'Information content entity', 'http://bioontology.org/projects/ontologies/birnlex#birnlex_11000', 'Non-realizable information entity')
#
# hello ('http://www.cvrgrid.org/files/ECGOntologyv1.owl#ECG_000000073', 'Ontology', 'http://www.cvrgrid.org/files/ECGOntologyv1.owl#ECG_000000290', 'Computational_Model', 'http://www.cvrgrid.org/files/ECGOntologyv1.owl#ECG_000000205', 'Data_Resource', 'http://www.cvrgrid.org/files/ECGOntologyv1.owl#ECG_000000336', 'Information_Resource', 'http://www.cvrgrid.org/files/ECGOntologyv1.owl#ECG_000000594', 'Resource', 'http://www.ifomis.org/snap#ObjectBoundary', 'ObjectBoundary')
#
# hello ('http://edamontology.org/topic_0089', 'Ontology and terminology', 'http://edamontology.org/topic_0605', 'Informatics', 'http://edamontology.org/topic_0003', 'Topic', None, None, None, None, None, None)
#
# hello ('http://edamontology.org/topic_0089', 'Ontology and terminology', 'http://edamontology.org/topic_0605', 'Informatics', 'http://edamontology.org/topic_0003', 'Topic', None, None, None, None, None, None)
#
# hello ('http://edamontology.org/topic_0089', 'Ontology and terminology', 'http://edamontology.org/topic_0605', 'Informatics', 'https://identifiers.org/ito:ITO_01680', 'Knowledge domain', 'https://identifiers.org/ito:Topic', 'Topic', None, None, None, None)
#
# hello ('http://purl.obolibrary.org/obo/GSSO_009995', 'ontology', 'http://purl.bioontology.org/ontology/MESH/D008678', 'metaphysics', 'http://purl.obolibrary.org/obo/GSSO_003088', 'basic philosophy', 'http://purl.bioontology.org/ontology/MESH/D010684', 'philosophy', 'http://purl.obolibrary.org/obo/GSSO_002368', 'basic humanities', 'http://purl.obolibrary.org/obo/GSSO_002346', 'humanities')
#
# hello ('http://protege.stanford.edu/ontologies/metadata/BioPortalMetadata.owl#Ontology', 'Ontology', 'http://protege.stanford.edu/ontologies/ChAO/changes.rdfs#AnnotatableThing', 'AnnotatableThing', 'http://www.w3.org/2000/01/rdf-schema#Resource', 'Resource', None, None, None, None, None, None)
#
# hello ('http://cui.unige.ch/isi/onto/tok/TOK.owl#Ontology', 'Ontology', 'http://cui.unige.ch/isi/onto/tok/TOK.owl#TOK_Resource', 'TOK_Resource', None, None, None, None, None, None, None, None)
#
# hello ('http://purl.jp/bio/4/id/200906024075521203', 'ontology', 'http://purl.jp/bio/4/subject/BA01_cat', 'Terms related to Documentation and information science', 'http://purl.jp/bio/4/subject/LS_ur_c/OWLClass_00000000000000000470', 'Management science and system engineering', None, None, None, None, None, None)
