# %% [markdown]
# # Medical Name Entity Recognition
# 1. I want you to apply Natural Language tools to the unstrutured medical data and provide some clean outputs.
# For example:
# **Input:** Itching on the whole body might be a symptom of an underlying illness, such as liver disease, kidney disease, anemia, diabetes, thyroid problems and certain cancers. Nerve disorders. Examples include multiple sclerosis, pinched nerves and shingles (herpes zoster). Psychiatric conditions.
#
# **Output:** Itching, illness, liver disease, kidney disease, anemia, diabetes, thyroid, cancer, Nerve disorders, sclerosis, pinched nerves, shingles, herpes zoster, Psychiatric conditions.
#
# 2. This is an interesting thing and I don't think much diffcult. You can use NLP techniques like sentence detection, word detection, stop-word removal, etc to clean the data and then you can use the trained Medical Name entity recognition algorithms to find medical concepts.
#
# 3. These library can be explored for NLP tasks. Some of the popular NLP libraries for data cleaning include:
#
# NLTK (Natural Language Toolkit): NLTK is a comprehensive library for NLP tasks, including data cleaning, tokenization, stemming, lemmatization, part-of-speech tagging, and more.
#
# spaCy: spaCy is a fast and efficient NLP library that provides functionalities for tokenization, named entity recognition, and part-of-speech tagging, which can be useful for data cleaning.
#
# TextBlob: TextBlob is built on top of NLTK and provides a simplified interface for common NLP tasks, including text cleaning and sentiment analysis.
#
# gensim: While gensim is primarily known for topic modeling, it also offers tools for data preprocessing, such as text cleaning and word tokenization.
#
# BeautifulSoup: BeautifulSoup is not an NLP library per se, but it is a widely used library for parsing and extracting data from HTML and XML documents, which can be helpful when dealing with web text data.
#
# regex (re module): Python's built-in re module provides support for regular expressions, which are powerful tools for pattern matching and text cleaning.
#
# 4. For medical name entity recognition try to explore this link --> https://paperswithcode.com/task/medical-named-entity-recognition

# %%
import sqlite3

# %%
conn = sqlite3.connect("hierarchyMedicalConcepts.db")
cursor = conn.cursor()
# drop the table first and only then create
dropQuery= "DROP TABLE IF EXISTS hierarchyMedicalConcepts"
cursor.execute(dropQuery)
cursor.execute("""
    CREATE TABLE IF NOT EXISTS hierarchyMedicalConcepts(
        classDetailsId NVARCHAR(160),
        prefLabelParent NVARCHAR(160),
        distance1ID NVARCHAR(160) DEFAULT NULL,
        prefLabel1 NVARCHAR(160) DEFAULT NULL,
        distance2ID NVARCHAR(160) DEFAULT NULL,
        prefLabel2 NVARCHAR(160) DEFAULT NULL,
        distance3ID NVARCHAR(160) DEFAULT NULL,
        prefLabel3 NVARCHAR(160) DEFAULT NULL,
        distance4ID NVARCHAR(160) DEFAULT NULL,
        prefLabel4 NVARCHAR(160) DEFAULT NULL,
        distance5ID NVARCHAR(160) DEFAULT NULL,
        prefLabel5 NVARCHAR(160) DEFAULT NULL
    )
""")

# %%
displayAllQuery="PRAGMA table_info (hierarchyMedicalConcepts)"#"Select * from hierarchyMedicalConcepts"
cursor.execute(displayAllQuery)
results = cursor.fetchall()
print(results)
#for row in results:
 # display += f"classDetailsId: {row[0]}, distance1: {row[1]}, distance2: {row[2]}, distance3: {row[3]}, distance4:{row[4]}, distance5:{row[5]}"
# Out:
# [(0, 'classDetailsId', 'NVARCHAR(160)', 0, None, 0), (1, 'prefLabelParent', 'NVARCHAR(160)', 0, None, 0), (2, 'distance1ID', 'NVARCHAR(160)', 0, 'NULL', 0), (3, 'prefLabel1', 'NVARCHAR(160)', 0, 'NULL', 0), (4, 'distance2ID', 'NVARCHAR(160)', 0, 'NULL', 0), (5, 'prefLabel2', 'NVARCHAR(160)', 0, 'NULL', 0), (6, 'distance3ID', 'NVARCHAR(160)', 0, 'NULL', 0), (7, 'prefLabel3', 'NVARCHAR(160)', 0, 'NULL', 0), (8, 'distance4ID', 'NVARCHAR(160)', 0, 'NULL', 0), (9, 'prefLabel4', 'NVARCHAR(160)', 0, 'NULL', 0), (10, 'distance5ID', 'NVARCHAR(160)', 0, 'NULL', 0), (11, 'prefLabel5', 'NVARCHAR(160)', 0, 'NULL', 0)]

# %%
# Code here

# %% [markdown]
# # NESTED Dictionary creation for Bioportal Onotologies Generated data about Hierarchies.
#
# **Example Input:**
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/G-A425
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G-A200
# 			prefLabel: Positive
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G-A000
# 			prefLabel: Severity of illness, NOS
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G
# 			prefLabel: GENERAL LINKAGE/MODIFIERS
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 3
#
# **Example output in Nested Dictionary Form:**
# hierarchies = {
#     1: {
#         'hiearachy_1': 'Positive',
#         'hiearachy_2': 'Severity of illness, NOS',
#         'hiearachy_3': 'GENERAL LINKAGE/MODIFIERS'
#         'match_type': 'PREF'
#     },
#     2: {
#         'hiearachy_1': 'Positive',
#         'hiearachy_2': 'Severity of illness',
#         'hiearachy_3': 'GENERAL LINKAGE/MODIFIERS'
#         'match_type': 'Synon'
#     }
# }
#
# Things to consider:
# 1. Data should be in English language, translate or remove any content out of english.
# 2. Try to remove repetatives.
# 3. Python dictionary default size may exceed. Try using json format and create file instead.

# %%
import urllib.request, urllib.error, urllib.parse
import json
import os
#from typing import None
from pprint import pprint

REST_URL = "http://data.bioontology.org"
API_KEY = "396993d0-4ce2-4123-93de-214e9b9ebcf2"
concepts_list=['sciatic pain, swollen feet, pregnancy']
# BIOPORTAL SHOWS Matches in 21 ontologies

def get_json(url):
    opener = urllib.request.build_opener()
    opener.addheaders = [('Authorization', 'apikey token=' + API_KEY)]
    return json.loads(opener.open(url).read())

def print_annotations(annotations, get_class=True):
    for result in annotations:
        class_details = result["annotatedClass"]
        if get_class:
            try:
                class_details = get_json(result["annotatedClass"]["links"]["self"])
                classDetailsId=class_details["@id"]
                prefLabelParent=str(class_details["prefLabel"])
            except urllib.error.HTTPError:
                print(f"Error retrieving {result['annotatedClass']['@id']}")
                continue
        print("Class details")
        print("\tid: " + class_details["@id"])
        print("\tprefLabel: " + str(class_details["prefLabel"]))
        print("\tontology: " + class_details["links"]["ontology"])

        print("Annotation details")
        for annotation in result["annotations"]:
            print("\tfrom: " + str(annotation["from"]))
            print("\tto: " + str(annotation["to"]))
            print("\tmatch type: " + annotation["matchType"])

        if result["hierarchy"]:
            print("\n\tHierarchy annotations")
            for annotation in result["hierarchy"]:
                try:
                    class_details = get_json(annotation["annotatedClass"]["links"]["self"])
                except urllib.error.HTTPError:
                    print(f"Error retrieving {annotation['annotatedClass']['@id']}")
                    continue
                pref_label = class_details["prefLabel"] or "no label"
                print("\t\tClass details")
                print("\t\t\tid: " + class_details["@id"])
                print("\t\t\tprefLabel: " + str(class_details["prefLabel"]))
                print("\t\t\tontology: " + class_details["links"]["ontology"])
                print("\t\t\tdistance from originally annotated class: " + str(annotation["distance"]))

                if str(annotation["distance"])=="1":
                  prefLabel1=pref_label
                  distance1ID=class_details["@id"]
                  # setting initial value to NULL for rest Hierarchies
                  prefLabel2 = None
                  distance2ID= None
                  prefLabel3=None
                  distance3ID=None
                  prefLabel4=None
                  distance4ID=None
                  prefLabel5=None
                  distance5ID=None
                  pass
                elif str(annotation["distance"])=="2":
                  prefLabel2=pref_label
                  distance2ID=class_details["@id"]
                  pass
                elif str(annotation["distance"])=="3":
                  prefLabel3=pref_label
                  distance3ID=class_details["@id"]
                  pass
                elif str(annotation["distance"])=="4":
                  prefLabel4=pref_label
                  distance4ID=class_details["@id"]
                  pass
                elif str(annotation["distance"])=="5":
                  prefLabel5=pref_label
                  distance5ID=class_details["@id"]
                  pass

            insertQuery="INSERT INTO hierarchyMedicalConcepts (classDetailsId,prefLabelParent,prefLabel1,distance1ID,prefLabel2,distance2ID,prefLabel3,distance3ID,prefLabel4,distance4ID,prefLabel5,distance5ID) VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?,?) "
            conn.execute(insertQuery,(classDetailsId,prefLabelParent,prefLabel1,distance1ID,prefLabel2,distance2ID,prefLabel3,distance3ID,prefLabel4,distance4ID,prefLabel5,distance5ID))

        print("\n\n")

for i in concepts_list:
 text_to_annotate = i

# Annotate using the provided text
 annotations = get_json(REST_URL + "/annotator?text=" + urllib.parse.quote(text_to_annotate))

# Print out annotation details
 print_annotations(annotations)

# Annotate with hierarchy information
 annotations = get_json(REST_URL + "/annotator?max_level=5&text=" + urllib.parse.quote(text_to_annotate))
 print_annotations(annotations)

# Annotate with prefLabel, synonym, definition returned
 annotations = get_json(REST_URL + "/annotator?include=prefLabel,synonym,definition&text=" + urllib.parse.quote(text_to_annotate))
 print_annotations(annotations, False)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0002210
# 	prefLabel: bulbous
# 	ontology: https://data.bioontology.org/ontologies/FLOPO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001865
# 			prefLabel: spheroid
# 			ontology: https://data.bioontology.org/ontologies/FLOPO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0002007
# 			prefLabel: convex 3-D shape
# 			ontology: https://data.bioontology.org/ontologies/FLOPO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0002266
# 			prefLabel: 3-D shape
# 			ontology: https://data.bioontology.org/ontologies/FLOPO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000052
# 			prefLabel: shape
# 			ontology: https://data.bioontology.org/ontologies/FLOPO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/FLOPO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0002210
# 	prefLabel: bulbous
# 	ontology: https://data.bioontology.org/ontologies/ZP
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001865
# 			prefLabel: spheroid
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0002007
# 			prefLabel: convex 3-D shape
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0002266
# 			prefLabel: 3-D shape
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000052
# 			prefLabel: shape
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0002210
# 	prefLabel: bulbous
# 	ontology: https://data.bioontology.org/ontologies/UPHENO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001865
# 			prefLabel: spheroid
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0002007
# 			prefLabel: convex 3-D shape
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0002266
# 			prefLabel: 3-D shape
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000052
# 			prefLabel: shape
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.org/obo/owl/PATO#PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/BIOMODELS
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.org/obo/owl/PATO#PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/BIOMODELS
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.org/obo/owl/PATO#PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/BIOMODELS
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.org/obo/owl/PATO#PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/BIOMODELS
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.org/obo/owl/PATO#PATO_0000001
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/BIOMODELS
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://purl.org/obo/owl/PATO#PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/HUPSON
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.org/obo/owl/PATO#PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/HUPSON
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.org/obo/owl/PATO#PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/HUPSON
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.org/obo/owl/PATO#PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/HUPSON
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/snap#Quality
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/HUPSON
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/snap#SpecificallyDependentContinuant
# 			prefLabel: specifically_dependent_continuant
# 			ontology: https://data.bioontology.org/ontologies/HUPSON
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/NIFDYS
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/NIFDYS
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/NIFDYS
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/NIFDYS
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000001
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/NIFDYS
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000019
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/NIFDYS
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000020
# 			prefLabel: specifically dependent continuant
# 			ontology: https://data.bioontology.org/ontologies/NIFDYS
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/PDRO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/PDRO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/PDRO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/PDRO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000019
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/PDRO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000020
# 			prefLabel: specifically dependent continuant
# 			ontology: https://data.bioontology.org/ontologies/PDRO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000002
# 			prefLabel: continuant
# 			ontology: https://data.bioontology.org/ontologies/PDRO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/PATO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/PATO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/PATO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/PATO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000001
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/PATO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000020
# 			prefLabel: specifically dependent continuant
# 			ontology: https://data.bioontology.org/ontologies/PATO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/NIFSTD
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000001
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000019
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000020
# 			prefLabel: specifically dependent continuant
# 			ontology: https://data.bioontology.org/ontologies/NIFSTD
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000001
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000020
# 			prefLabel: specifically dependent continuant
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/MS
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/MS
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/MS
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/MS
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000001
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/MS
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/FLOPO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/FLOPO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/FLOPO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/FLOPO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000001
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/FLOPO
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/ZP
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000001
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000019
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000020
# 			prefLabel: specifically dependent continuant
# 			ontology: https://data.bioontology.org/ontologies/ZP
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/UPHENO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000141
# 			prefLabel: structure
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001241
# 			prefLabel: physical object quality
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000019
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000020
# 			prefLabel: specifically dependent continuant
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000002
# 			prefLabel: continuant
# 			ontology: https://data.bioontology.org/ontologies/UPHENO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://www.semanticweb.org/ontologies/2012/11/abnormalities.owl#phenodb:1617
# 	prefLabel: Feet
# 	ontology: https://data.bioontology.org/ontologies/IFAR
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.semanticweb.org/ontologies/2012/11/abnormalities.owl#phenodb:1354
# 			prefLabel: Skeletal
# 			ontology: https://data.bioontology.org/ontologies/IFAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.semanticweb.org/ontologies/2012/11/abnormalities.owl#phenodb:0000
# 			prefLabel: ABNORMALITY
# 			ontology: https://data.bioontology.org/ontologies/IFAR
# 			distance from originally annotated class: 2
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/259051005
# 	prefLabel: ft
# 	ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/258676003
# 			prefLabel: Non-SI unit of length
# 			ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/258667005
# 			prefLabel: Unit of length
# 			ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/767524001
# 			prefLabel: Unit of measure
# 			ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/362981000
# 			prefLabel: Qualifier value
# 			ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#31158
# 	prefLabel: 31158
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://sbmi.uth.tmc.edu/ontology/ochv#CHV_Concept
# 			prefLabel: CHV_Concept
# 			ontology: https://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2004/02/skos/core#Concept
# 			prefLabel: Concept
# 			ontology: https://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 2
#
#
#
# Class details
# 	id: http://www.co-ode.org/ontologies/galen#feet
# 	prefLabel: feet
# 	ontology: https://data.bioontology.org/ontologies/GALEN
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#LengthUnit
# 			prefLabel: LengthUnit
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#PrimitiveUnit
# 			prefLabel: PrimitiveUnit
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#Unit
# 			prefLabel: Unit
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#ModifierConcept
# 			prefLabel: ModifierConcept
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#DomainCategory
# 			prefLabel: DomainCategory
# 			ontology: https://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://id.nlm.nih.gov/mesh/D005528
# 	prefLabel: Foot
# 	ontology: https://data.bioontology.org/ontologies/MDM
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/OMIM/MTHU000075
# 	prefLabel: Feet
# 	ontology: https://data.bioontology.org/ontologies/OMIM
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/OMIM/MTHU000029
# 			prefLabel: SKELETAL
# 			ontology: https://data.bioontology.org/ontologies/OMIM
# 			distance from originally annotated class: 1
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#C0347981
# 	prefLabel: feet
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://sbmi.uth.tmc.edu/ontology/ochv#UMLS_Concept
# 			prefLabel: UMLS_Concept
# 			ontology: https://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2004/02/skos/core#Concept
# 			prefLabel: Concept
# 			ontology: https://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 2
#
#
#
# Class details
# 	id: http://sig.uw.edu/fma#Foot
# 	prefLabel: foot
# 	ontology: https://data.bioontology.org/ontologies/HUPSON
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://onto.eva.mpg.de/ontologies/gfo-bio.owl#Anatomical_part
# 			prefLabel: anatomical part
# 			ontology: https://data.bioontology.org/ontologies/HUPSON
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/snap#Object
# 			prefLabel: object
# 			ontology: https://data.bioontology.org/ontologies/HUPSON
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/snap#MaterialEntity
# 			prefLabel: material_entity
# 			ontology: https://data.bioontology.org/ontologies/HUPSON
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/snap#IndependentContinuant
# 			prefLabel: independent_continuant
# 			ontology: https://data.bioontology.org/ontologies/HUPSON
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/snap#Continuant
# 			prefLabel: continuant
# 			ontology: https://data.bioontology.org/ontologies/HUPSON
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/RCD/X806G
# 	prefLabel: feet
# 	ontology: https://data.bioontology.org/ontologies/RCD
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/X800B
# 			prefLabel: Non-SI unit of length
# 			ontology: https://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/X8002
# 			prefLabel: Unit of length
# 			ontology: https://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/X8001
# 			prefLabel: Unit
# 			ontology: https://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/.....
# 			prefLabel: Read thesaurus
# 			ontology: https://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://www.owl-ontologies.com/unnamed.owl#RID13283
# 	prefLabel: FEET
# 	ontology: https://data.bioontology.org/ontologies/DERMLEX
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.owl-ontologies.com/unnamed.owl#RID13278
# 			prefLabel: FOOT PLANTAR
# 			ontology: https://data.bioontology.org/ontologies/DERMLEX
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.owl-ontologies.com/unnamed.owl#RID13102
# 			prefLabel: BODY LOCATIONS
# 			ontology: https://data.bioontology.org/ontologies/DERMLEX
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://www.owl-ontologies.com/unnamed.owl#RID13076
# 			prefLabel: BODY LOCATIONS DISTRIBUTIONS
# 			ontology: https://data.bioontology.org/ontologies/DERMLEX
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.owl-ontologies.com/unnamed.owl#RID13075
# 			prefLabel: DLP ENTRIES
# 			ontology: https://data.bioontology.org/ontologies/DERMLEX
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.owl-ontologies.com/unnamed.owl#RID1
# 			prefLabel: DermLex term
# 			ontology: https://data.bioontology.org/ontologies/DERMLEX
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#5187
# 	prefLabel: pes
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://sbmi.uth.tmc.edu/ontology/ochv#CHV_Concept
# 			prefLabel: CHV_Concept
# 			ontology: https://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2004/02/skos/core#Concept
# 			prefLabel: Concept
# 			ontology: https://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 2
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/MESH/D005528
# 	prefLabel: Foot
# 	ontology: https://data.bioontology.org/ontologies/MESH
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MESH/D035002
# 			prefLabel: Lower Extremity
# 			ontology: https://data.bioontology.org/ontologies/MESH
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MESH/D005121
# 			prefLabel: Extremities
# 			ontology: https://data.bioontology.org/ontologies/MESH
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MESH/D001829
# 			prefLabel: Body Regions
# 			ontology: https://data.bioontology.org/ontologies/MESH
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C191656
# 	prefLabel: Pregnant Subject
# 	ontology: https://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C41189
# 			prefLabel: Study Subject
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C79916
# 			prefLabel: Investigative Subject
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C48910
# 			prefLabel: Subject
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20181
# 			prefLabel: Conceptual Entity
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/CSEO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://scai.fraunhofer.de/CSEO#CSEO_03000020
# 			prefLabel: Finding
# 			ontology: https://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.ifomis.org/snap#Disposition
# 			prefLabel: disposition
# 			ontology: https://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://www.ifomis.org/snap#RealizableEntity
# 			prefLabel: realizable_entity
# 			ontology: https://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ifomis.org/snap#SpecificallyDependentContinuant
# 			prefLabel: specifically_dependent_continuant
# 			ontology: https://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.ifomis.org/snap#DependentContinuant
# 			prefLabel: dependent_continuant
# 			ontology: https://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0002950
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/CCONT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GO_0000003
# 			prefLabel: reproduction
# 			ontology: https://data.bioontology.org/ontologies/CCONT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GO_0008150
# 			prefLabel: biological_process
# 			ontology: https://data.bioontology.org/ontologies/CCONT
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000015
# 			prefLabel: process
# 			ontology: https://data.bioontology.org/ontologies/CCONT
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ebi.ac.uk/efo/EFO_0000001
# 			prefLabel: experimental factor
# 			ontology: https://data.bioontology.org/ontologies/CCONT
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0002950
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/EFO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GO_0000003
# 			prefLabel: reproduction
# 			ontology: https://data.bioontology.org/ontologies/EFO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GO_0008150
# 			prefLabel: biological_process
# 			ontology: https://data.bioontology.org/ontologies/EFO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000015
# 			prefLabel: process
# 			ontology: https://data.bioontology.org/ontologies/EFO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ebi.ac.uk/efo/EFO_0000001
# 			prefLabel: experimental factor
# 			ontology: https://data.bioontology.org/ontologies/EFO
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0002950
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/HSPO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GO_0000003
# 			prefLabel: reproduction
# 			ontology: https://data.bioontology.org/ontologies/HSPO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GO_0008150
# 			prefLabel: biological_process
# 			ontology: https://data.bioontology.org/ontologies/HSPO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000015
# 			prefLabel: process
# 			ontology: https://data.bioontology.org/ontologies/HSPO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ebi.ac.uk/efo/EFO_0000001
# 			prefLabel: experimental factor
# 			ontology: https://data.bioontology.org/ontologies/HSPO
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/OMIT_0012209
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/OMIT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/OMIT_0013022
# 			prefLabel: Reproduction
# 			ontology: https://data.bioontology.org/ontologies/OMIT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/OMIT_0026442
# 			prefLabel: Reproductive Physiological Processes
# 			ontology: https://data.bioontology.org/ontologies/OMIT
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/OMIT_0026441
# 			prefLabel: Reproductive Physiological Phenomena
# 			ontology: https://data.bioontology.org/ontologies/OMIT
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/OMIT_0013025
# 			prefLabel: Reproductive and Urinary Physiological Phenomena
# 			ontology: https://data.bioontology.org/ontologies/OMIT
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://purl.obolibrary.org/obo/OMIT_0001007
# 			prefLabel: Phenomena and Processes Category
# 			ontology: https://data.bioontology.org/ontologies/OMIT
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/CSP/2400-8114
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/CRISP
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/CSP/2586-6130
# 			prefLabel: reproduction
# 			ontology: https://data.bioontology.org/ontologies/CRISP
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/CSP/0418-4826
# 			prefLabel: life cycle
# 			ontology: https://data.bioontology.org/ontologies/CRISP
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/CSP/1354-3663
# 			prefLabel: growth/development
# 			ontology: https://data.bioontology.org/ontologies/CRISP
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.bioontology.org/ontology/CSP/0418-4282
# 			prefLabel: biology
# 			ontology: https://data.bioontology.org/ontologies/CRISP
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/MESH/D011247
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/MESH
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MESH/D012098
# 			prefLabel: Reproduction
# 			ontology: https://data.bioontology.org/ontologies/MESH
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MESH/D055703
# 			prefLabel: Reproductive Physiological Phenomena
# 			ontology: https://data.bioontology.org/ontologies/MESH
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MESH/D012101
# 			prefLabel: Reproductive and Urinary Physiological Phenomena
# 			ontology: https://data.bioontology.org/ontologies/MESH
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/MEDDRA/10036556
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/MEDDRA
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MEDDRA/10029772
# 			prefLabel: Normal pregnancy, labour and delivery
# 			ontology: https://data.bioontology.org/ontologies/MEDDRA
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MEDDRA/10010273
# 			prefLabel: Pregnancy, labour, delivery and postpartum conditions
# 			ontology: https://data.bioontology.org/ontologies/MEDDRA
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/MEDDRA/10036585
# 			prefLabel: Pregnancy, puerperium and perinatal conditions
# 			ontology: https://data.bioontology.org/ontologies/MEDDRA
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.org/twc/HHEAR_00489
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.org/twc/HHEAR_00119
# 			prefLabel: Pregnancy Characteristic
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000417
# 			prefLabel: time interval
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/NCIT_C90339
# 			prefLabel: Maternal Prenatal Stage
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.org/twc/HHEAR_00507
# 			prefLabel: From Conception
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.org/twc/HHEAR_00508
# 			prefLabel: Relative Time
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000391
# 			prefLabel: time measurement
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000258
# 			prefLabel: dimensional quantity
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000052
# 			prefLabel: quantity
# 			ontology: https://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C25742
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C21173
# 			prefLabel: Reproductive Process
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C19988
# 			prefLabel: Organismal Process
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C17828
# 			prefLabel: Biological Process
# 			ontology: https://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://www.semanticweb.org/ontologies/2012/0/Ontology1325521724189.owl#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/CTO-NDD
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.semanticweb.org/ontologies/2012/0/Ontology1325521724189.owl#Exclusion_criteria
# 			prefLabel: Exclusion criteria
# 			ontology: https://data.bioontology.org/ontologies/CTO-NDD
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.semanticweb.org/ontologies/2012/0/Ontology1325521724189.owl#Recruitment_criteria
# 			prefLabel: Recruitment criteria
# 			ontology: https://data.bioontology.org/ontologies/CTO-NDD
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://www.co-ode.org/ontologies/ont.owl#Recruitment_of_patients
# 			prefLabel: Patient recruitment
# 			ontology: https://data.bioontology.org/ontologies/CTO-NDD
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.semanticweb.org/ontologies/2012/0/Ontology1325521724189.owl#Study_Conduct_Sub-Domain
# 			prefLabel: Conduct of the study
# 			ontology: https://data.bioontology.org/ontologies/CTO-NDD
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.co-ode.org/ontologies/ont.owl#Clinical_trial
# 			prefLabel: Clinical trial
# 			ontology: https://data.bioontology.org/ontologies/CTO-NDD
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://localhost/plosthes.2017-1#10071
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/PLOSTHES
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.bioontology.org/pma.owl#PMA_1959
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/PMA
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.jp/bio/4/id/200906033179058270
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/IOBC
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.jp/bio/4/id/200906067736606163
# 			prefLabel: reproduction (biology)
# 			ontology: https://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.jp/bio/4/subject/System_cat
# 			prefLabel: Biological phenomenon, process, and state
# 			ontology: https://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.jp/bio/4/subject/LS_ur_c/OWLClass_00000000000000000665
# 			prefLabel: Terms related to life science
# 			ontology: https://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.jp/bio/4/subject/IA07
# 			prefLabel: Phenomena
# 			ontology: https://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.jp/bio/4/subject/I
# 			prefLabel: General
# 			ontology: https://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/LP207970-7
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.pepathway.org/peo/1.2#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/PE-O
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.pepathway.org/peo/1.2#Basic_attribute_on_pregnancy
# 			prefLabel: Basic attribute on pregnancy
# 			ontology: https://data.bioontology.org/ontologies/PE-O
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/snap#Quality
# 			prefLabel: quality
# 			ontology: https://data.bioontology.org/ontologies/PE-O
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/snap#SpecificallyDependentContinuant
# 			prefLabel: specifically_dependent_continuant
# 			ontology: https://data.bioontology.org/ontologies/PE-O
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/snap#DependentContinuant
# 			prefLabel: dependent_continuant
# 			ontology: https://data.bioontology.org/ontologies/PE-O
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/snap#Continuant
# 			prefLabel: continuant
# 			ontology: https://data.bioontology.org/ontologies/PE-O
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/NCIT_C25742
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/BERO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/NCIT_C21173
# 			prefLabel: Reproductive Process
# 			ontology: https://data.bioontology.org/ontologies/BERO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/NCIT_C19988
# 			prefLabel: Organismal Process
# 			ontology: https://data.bioontology.org/ontologies/BERO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/NCIT_C17828
# 			prefLabel: Biological Process
# 			ontology: https://data.bioontology.org/ontologies/BERO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686.785.760.769
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/RH-MESH
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686.785.760
# 			prefLabel: Reproduction
# 			ontology: https://data.bioontology.org/ontologies/RH-MESH
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686.785
# 			prefLabel: Reproductive Physiological Processes
# 			ontology: https://data.bioontology.org/ontologies/RH-MESH
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686
# 			prefLabel: Reproductive Physiological Phenomena
# 			ontology: https://data.bioontology.org/ontologies/RH-MESH
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08
# 			prefLabel: Reproductive and Urinary Physiological Phenomena
# 			ontology: https://data.bioontology.org/ontologies/RH-MESH
# 			distance from originally annotated class: 4
#
#
#
# Class details
# 	id: http://www.ifomis.org/acgt/1.0#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/ACGT-MO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.ifomis.org/acgt/1.0#OrganismalProcess
# 			prefLabel: OrganismalProcess
# 			ontology: https://data.bioontology.org/ontologies/ACGT-MO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.ifomis.org/acgt/1.0#NaturalProcess
# 			prefLabel: NaturalProcess
# 			ontology: https://data.bioontology.org/ontologies/ACGT-MO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/span#Process
# 			prefLabel: process
# 			ontology: https://data.bioontology.org/ontologies/ACGT-MO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/span#ProcessualEntity
# 			prefLabel: processual_entity
# 			ontology: https://data.bioontology.org/ontologies/ACGT-MO
# 			distance from originally annotated class: 4
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.1/span#Occurrent
# 			prefLabel: occurrent
# 			ontology: https://data.bioontology.org/ontologies/ACGT-MO
# 			distance from originally annotated class: 5
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/XCO_0000412
# ...
# 	prefLabel: bulbous
# 	ontology: https://data.bioontology.org/ontologies/ZP
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0002210
# 	prefLabel: bulbous
# 	ontology: https://data.bioontology.org/ontologies/UPHENO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.org/obo/owl/PATO#PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/BIOMODELS
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.org/obo/owl/PATO#PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/HUPSON
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/NIFDYS
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/PDRO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/PATO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/NIFSTD
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/MS
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/FLOPO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/ZP
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0001851
# 	prefLabel: swollen
# 	ontology: https://data.bioontology.org/ontologies/UPHENO
# Annotation details
# 	from: 15
# 	to: 21
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.semanticweb.org/ontologies/2012/11/abnormalities.owl#phenodb:1617
# 	prefLabel: Feet
# 	ontology: https://data.bioontology.org/ontologies/IFAR
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/259051005
# 	prefLabel: ft
# 	ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#31158
# 	prefLabel: 31158
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
#
#
# Class details
# 	id: http://www.co-ode.org/ontologies/galen#feet
# 	prefLabel: feet
# 	ontology: https://data.bioontology.org/ontologies/GALEN
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://id.nlm.nih.gov/mesh/D005528
# 	prefLabel: Foot
# 	ontology: https://data.bioontology.org/ontologies/MDM
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/OMIM/MTHU000075
# 	prefLabel: Feet
# 	ontology: https://data.bioontology.org/ontologies/OMIM
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#C0347981
# 	prefLabel: feet
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sig.uw.edu/fma#Foot
# 	prefLabel: foot
# 	ontology: https://data.bioontology.org/ontologies/HUPSON
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/RCD/X806G
# 	prefLabel: feet
# 	ontology: https://data.bioontology.org/ontologies/RCD
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.owl-ontologies.com/unnamed.owl#RID13283
# 	prefLabel: FEET
# 	ontology: https://data.bioontology.org/ontologies/DERMLEX
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#5187
# 	prefLabel: pes
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/MESH/D005528
# 	prefLabel: Foot
# 	ontology: https://data.bioontology.org/ontologies/MESH
# Annotation details
# 	from: 23
# 	to: 26
# 	match type: SYN
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C191656
# 	prefLabel: Pregnant Subject
# 	ontology: https://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: SYN
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/CSEO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0002950
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/CCONT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0002950
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/EFO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ebi.ac.uk/efo/EFO_0002950
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/HSPO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/OMIT_0012209
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/OMIT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/CSP/2400-8114
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/CRISP
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/MESH/D011247
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/MESH
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/MEDDRA/10036556
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/MEDDRA
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.org/twc/HHEAR_00489
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C25742
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.semanticweb.org/ontologies/2012/0/Ontology1325521724189.owl#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/CTO-NDD
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://localhost/plosthes.2017-1#10071
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/PLOSTHES
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.bioontology.org/pma.owl#PMA_1959
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/PMA
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.jp/bio/4/id/200906033179058270
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/IOBC
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/LP207970-7
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.pepathway.org/peo/1.2#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/PE-O
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/NCIT_C25742
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/BERO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686.785.760.769
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/RH-MESH
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ifomis.org/acgt/1.0#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/ACGT-MO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/XCO_0000412
# 	prefLabel: gestation
# 	ontology: https://data.bioontology.org/ontologies/XCO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: SYN
#
#
#
# Class details
# 	id: http://www.owl-ontologies.com/Ontology1358660052.owl#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/PEDTERM
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/289908002
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://mental-ontology.com/mental_health_bfo.owl#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/MHMO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.jp/bio/4/id/kb0000001620
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/IOBC
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.semanticweb.org/administrator/ontologies/2022/0/untitled-ontology-34#OWLClassac85ad9b_de81_4bcf_b9fd_6ea4b49a2e69
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/WWECA
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bmi.utah.edu/ontologies/hfontology/C0032961
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/HFO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/NDFRT/N0000010195
# 	prefLabel: Pregnancy [Disease/Finding]
# 	ontology: https://data.bioontology.org/ontologies/NDFRT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: SYN
#
#
#
# Class details
# 	id: http://www.gamuts.net/entity#pregnancy
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/GAMUTS
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ontology.apa.org/apaonto/termsonlyOUT%20(5).owl#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/APAONTO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://hadatac.org/ont/chear#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.semanticweb.org/luyu/ontologies/2021/3/pregnancy_information_needs_ontology#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/PINO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/RCD/Xa4eG
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/RCD
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.co-ode.org/ontologies/galen#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/GALEN
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/WHO/0663
# 	prefLabel: PREGNANCY UNINTENDED
# 	ontology: https://data.bioontology.org/ontologies/WHO-ART
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/MTHU035048
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/77386006
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#C0032961
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/NLMVS/2.16.840.1.113883.3.526.3.378
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/NLMVS
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/LP100811-1
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#10047
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/LA6530-5
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.semanticweb.org/ontologies/chronic-diease-patient-education-ontology#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/CDPEO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.projecthalo.com/aura#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/AURA
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://phenomebrowser.net/ontologies/mesh/mesh.owl#D011247
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/RH-MESH
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/MEDLINEPLUS/C0032961
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/MEDLINEPLUS
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.icn.ch/icnp#Pregnancy
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/ICNP
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://radlex.org/RID/RID4941
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/RADLEX
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.semanticweb.org/ontologies/epo.owl#OPPIO_d000100
# 	prefLabel: pregnancy
# 	ontology: https://data.bioontology.org/ontologies/EPO
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/MTHU042911
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://bioportal/bioontology.org/ontologies/HIVO0004#OWLClass_00000010680792664081
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/HIVO004
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://id.nlm.nih.gov/mesh/D011247
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/MDM
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/LP133213-1
# 	prefLabel: Pregnancy
# 	ontology: https://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 29
# 	to: 37
# 	match type: PREF

# %%
cursor.execute("SELECT * FROM hierarchyMedicalConcepts")

# %%
rows = cursor.fetchall()

# Print the results
for row in rows:
    print(row)
# Out:
# ('http://www.limics.fr/ontologies/ontoparonmed#DouleurSciatique', 'sciatic pain', 'http://www.limics.fr/ontologies/ontoparonmed#DouleurNevralgique', 'Nerve pain', 'http://www.limics.fr/ontologies/ontoparonmed#DouleurNeurologique', 'neurological pain', 'http://www.limics.fr/ontologies/ontoparonmed#DouleurSpecifiee', 'specified pain', 'http://www.limics.fr/ontologies/ontoparonmed#Douleur', 'Pain function', 'http://www.limics.fr/ontologies/ontoparonmed#SigneClinique', 'clinical sign')
# ('http://www.tcmkg.com/ISPO/ISPO_00002087', 'Sciatica, bilateral', 'http://www.tcmkg.com/ISPO/ISPO_00001076', 'Polyarthralgias', 'http://www.tcmkg.com/ISPO/ISPO_00001816', 'Pain', 'http://www.tcmkg.com/ISPO/ISPO_00002649', 'Musculoskeletal system symptoms', 'http://www.tcmkg.com/ISPO/ISPO_99999999', 'symptoms', None, None)
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C53794', 'Adverse Event Associated with Pain', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C53781', 'Adverse Event by CTCAE Category', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C41331', 'Adverse Event', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C36291', 'Finding by Cause', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C3367', 'Finding', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C7057', 'Disease, Disorder or Finding')
# ('http://purl.bioontology.org/ontology/PMR.owl#Pain', 'Pain', 'http://purl.bioontology.org/ontology/PMR.owl#Functional_Rehabilitation', 'Functional_Rehabilitation', 'http://purl.bioontology.org/ontology/PMR.owl#Process', 'Process', 'http://purl.bioontology.org/ontology/PMR.owl#General_knowledge', 'General_knowledge', None, None, None, None)
# ('http://www.projecthalo.com/aura#Pain', 'Pain', 'http://www.projecthalo.com/aura#Condition', 'Condition', 'http://www.projecthalo.com/aura#State', 'State', 'http://www.projecthalo.com/aura#Event', 'Event', None, None, None, None)
# ('http://purl.obolibrary.org/obo/OGMS_0000085', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://purl.obolibrary.org/obo/BFO_0000015', 'process', 'http://purl.obolibrary.org/obo/BFO_0000003', 'occurrent', 'http://purl.obolibrary.org/obo/BFO_0000001', 'entity', None, None)
# ('http://purl.obolibrary.org/obo/OGMS_0000085', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://purl.obolibrary.org/obo/OGMS_0000028', 'disease phenotype', 'http://purl.obolibrary.org/obo/OGMS_0000027', 'clinical phenotype', 'http://purl.obolibrary.org/obo/OGMS_0000023', 'phenotype', 'http://purl.obolibrary.org/obo/PATO_0001995', 'organismal quality')
# ('http://purl.obolibrary.org/obo/OGMS_0000085', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://purl.obolibrary.org/obo/BFO_0000015', 'process', 'http://purl.obolibrary.org/obo/BFO_0000003', 'occurrent', 'http://purl.obolibrary.org/obo/BFO_0000001', 'entity', None, None)
# ('http://purl.obolibrary.org/obo/OGMS_0000085', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://purl.obolibrary.org/obo/BFO_0000001', 'entity', None, None, None, None, None, None)
# ('http://purl.obolibrary.org/obo/OGMS_0000085', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://purl.obolibrary.org/obo/BFO_0000015', 'process', 'http://purl.obolibrary.org/obo/BFO_0000003', 'occurrent', 'http://purl.obolibrary.org/obo/BFO_0000001', 'entity', None, None)
# ('http://purl.obolibrary.org/obo/OGMS_0000085', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'specifically dependent continuant', 'http://purl.obolibrary.org/obo/BFO_0000002', 'continuant', None, None)
# ('http://purl.obolibrary.org/obo/OGMS_0000085', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://purl.obolibrary.org/obo/OGMS_0000015', 'clinical history', 'http://purl.obolibrary.org/obo/OGMS_0000014', 'clinical finding', 'http://purl.obolibrary.org/obo/IAO_0000027', 'data item', 'http://purl.obolibrary.org/obo/IAO_0000030', 'information content entity')
# ('http://purl.obolibrary.org/obo/OGMS_0000085', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://purl.obolibrary.org/obo/BFO_0000015', 'process', 'http://purl.obolibrary.org/obo/BFO_0000003', 'occurrent', 'http://purl.obolibrary.org/obo/BFO_0000001', 'entity', None, None)
# ('http://purl.obolibrary.org/obo/OGMS_0000085', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://purl.obolibrary.org/obo/OGMS_0000021', 'bodily feature of a patient', 'http://www.ifomis.org/bfo/1.1#Entity', 'entity', None, None, None, None)
# ('http://purl.obolibrary.org/obo/OGMS_0000085', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://purl.obolibrary.org/obo/BFO_0000001', 'entity', None, None, None, None, None, None)
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C125331', 'How Much Distress Pain', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173393', 'How Much Distress', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173348', 'Distress Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173160', 'Feelings Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C91102', 'Clinical or Research Assessment Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20993', 'Research or Clinical Assessment Tool')
# ('http://purl.bioontology.org/ontology/NDFRT/N0000002278', 'Pain [Disease/Finding]', 'http://purl.bioontology.org/ontology/NDFRT/N0000002173', 'Neurologic Manifestations [Disease/Finding]', 'http://purl.bioontology.org/ontology/NDFRT/N0000002159', 'Nervous System Diseases [Disease/Finding]', 'http://purl.bioontology.org/ontology/NDFRT/N0000000004', 'Diseases, Manifestations or Physiologic States [Disease/Finding]', 'http://purl.bioontology.org/ontology/NDFRT/NOCODE', 'National Drug File - Reference Terminology', None, None)
# ('http://semanticscience.org/resource/SIO_000951', 'pain', 'http://semanticscience.org/resource/SIO_000845', 'hurt', 'http://semanticscience.org/resource/SIO_000832', 'negative emotion', 'http://semanticscience.org/resource/SIO_000276', 'emotion', 'http://semanticscience.org/resource/SIO_001195', 'behaviour', 'http://semanticscience.org/resource/SIO_000006', 'process')
# ('http://semanticscience.org/resource/SIO_000951', 'pain', 'http://semanticscience.org/resource/SIO_000845', 'hurt', 'http://semanticscience.org/resource/SIO_000832', 'negative emotion', 'http://semanticscience.org/resource/SIO_000276', 'emotion', 'http://semanticscience.org/resource/SIO_001195', 'behaviour', 'http://semanticscience.org/resource/SIO_000006', 'process')
# ('http://semanticscience.org/resource/SIO_000951', 'pain', 'http://semanticscience.org/resource/SIO_000845', 'hurt', 'http://semanticscience.org/resource/SIO_000832', 'negative emotion', 'http://semanticscience.org/resource/SIO_000276', 'emotion', 'http://semanticscience.org/resource/SIO_001195', 'behaviour', 'http://semanticscience.org/resource/SIO_000006', 'process')
# ('http://semanticscience.org/resource/SIO_000951', 'pain', 'http://semanticscience.org/resource/SIO_000845', 'hurt', 'http://semanticscience.org/resource/SIO_000832', 'negative emotion', 'http://semanticscience.org/resource/SIO_000276', 'emotion', 'http://semanticscience.org/resource/SIO_001195', 'behaviour', 'http://semanticscience.org/resource/SIO_000006', 'process')
# ('http://semanticscience.org/resource/SIO_000951', 'pain', 'http://semanticscience.org/resource/SIO_000845', 'hurt', 'http://semanticscience.org/resource/SIO_000832', 'negative emotion', 'http://semanticscience.org/resource/SIO_000276', 'emotion', 'http://semanticscience.org/resource/SIO_001195', 'behaviour', 'http://semanticscience.org/resource/SIO_000006', 'process')
# ('http://semanticscience.org/resource/SIO_000951', 'pain', 'http://semanticscience.org/resource/SIO_000845', 'hurt', 'http://semanticscience.org/resource/SIO_000832', 'negative emotion', 'http://semanticscience.org/resource/SIO_000276', 'emotion', 'http://semanticscience.org/resource/SIO_001195', 'behaviour', 'http://semanticscience.org/resource/SIO_000006', 'process')
# ('http://semanticscience.org/resource/SIO_000951', 'pain', 'http://semanticscience.org/resource/SIO_000845', 'hurt', 'http://semanticscience.org/resource/SIO_000832', 'negative emotion', 'http://semanticscience.org/resource/SIO_000276', 'emotion', 'http://semanticscience.org/resource/SIO_001195', 'behaviour', 'http://purl.org/twc/HHEAR_00117', 'Physical And Mental Assessment')
# ('http://semanticscience.org/resource/SIO_000951', 'pain', 'http://semanticscience.org/resource/SIO_000845', 'hurt', 'http://semanticscience.org/resource/SIO_000832', 'negative emotion', 'http://semanticscience.org/resource/SIO_000276', 'emotion', 'http://purl.obolibrary.org/obo/NCIT_C16840', 'mental process', 'http://purl.obolibrary.org/obo/GO_0050877', 'nervous system process')
# ('http://www.semanticweb.org/ontologies/2012/11/abnormalities.owl#phenodb:1407', 'Pain', 'http://www.semanticweb.org/ontologies/2012/11/abnormalities.owl#phenodb:1355', 'General skeletal abnormalities', 'http://www.semanticweb.org/ontologies/2012/11/abnormalities.owl#phenodb:1354', 'Skeletal', 'http://www.semanticweb.org/ontologies/2012/11/abnormalities.owl#phenodb:0000', 'ABNORMALITY', None, None, None, None)
# ('http://www.semanticweb.org/ontologies/2010/10/BPO.owl#pain', 'pain', 'http://www.semanticweb.org/ontologies/2010/10/BPO.owl#physical_finding', 'physical_finding', None, None, None, None, None, None, None, None)
# ('http://www.semanticweb.org/zhenyuzhang/ontologies/2020/DRPSNPTO/Pain', 'Pain', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2020/DRPSNPTO/MedicalIllness', 'Medical Illness', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2020/DRPSNPTO/IntrapersonalCausativeFactor', 'Intrapersonal Causative Factor', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2020/DRPSNPTO/PrecipitatingFactor', 'Precipitating Factor', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2020/DRPSNPTO/PsychoticSymptomCausativeFactor', 'Psychotic Symptom Causative Factor', None, None)
# ('http://purl.jp/bio/4/id/201606007558454705', 'pain', 'http://purl.jp/bio/4/id/200906012659235956', 'Ache', 'http://purl.jp/bio/4/id/200906003227080073', 'symptom', 'http://purl.jp/bio/4/id/200906041631547545', 'Disease, and Symptom', 'http://purl.jp/bio/4/subject/I', 'General', None, None)
# ('http://purl.bioontology.org/ontology/MESH/D010146', 'Pain', 'http://purl.bioontology.org/ontology/MESH/D009461', 'Neurologic Manifestations', 'http://purl.bioontology.org/ontology/MESH/D012816', 'Signs and Symptoms', 'http://purl.bioontology.org/ontology/MESH/D013568', 'Pathological Conditions, Signs and Symptoms', None, None, None, None)
# ('http://bmi.utah.edu/ontologies/hfontology/C0030193', 'Pain', 'http://bmi.utah.edu/ontologies/hfontology/Signs_symptoms', 'Signs_symptoms', None, None, None, None, None, None, None, None)
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C124175', 'Pain Distress', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173346', 'Pain Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173219', 'Physical Feelings Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173160', 'Feelings Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C91102', 'Clinical or Research Assessment Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20993', 'Research or Clinical Assessment Tool')
# ('http://purl.obolibrary.org/obo/OMIT_0011149', 'Pain', 'http://purl.obolibrary.org/obo/OMIT_0013574', 'Sensation', 'http://purl.obolibrary.org/obo/OMIT_0012544', 'Psychophysiology', 'http://purl.obolibrary.org/obo/OMIT_0011805', 'Physiology', 'http://purl.obolibrary.org/obo/OMIT_0003051', 'Biological Science Disciplines', 'http://purl.obolibrary.org/obo/OMIT_0011790', 'Natural Science Disciplines')
# ('http://www.semanticweb.org/admin/ontologies/2022/7/MIO:00837', 'pain', 'http://www.semanticweb.org/admin/ontologies/2022/7/MIO:00146', 'phenotypic abnormality', 'http://www.semanticweb.org/admin/ontologies/2022/7/MIO:00023', 'clinical factor', 'http://www.semanticweb.org/admin/ontologies/2022/7/MIO:00004', 'influencing factor', 'http://www.semanticweb.org/admin/ontologies/2022/7/MIO:00000', 'myocardial infarction', None, None)
# ('http://purl.bioontology.org/ontology/SNOMEDCT/22253000', 'Pain', 'http://purl.bioontology.org/ontology/SNOMEDCT/276435006', 'Pain / sensation finding', 'http://purl.bioontology.org/ontology/SNOMEDCT/106147001', 'Sensory nervous system finding', 'http://purl.bioontology.org/ontology/SNOMEDCT/102957003', 'Neurological finding', 'http://purl.bioontology.org/ontology/SNOMEDCT/404684003', 'Clinical finding', None, None)
# ('http://cbmi.med.harvard.edu/asdphenotype#Class_677', 'Pain', 'http://cbmi.med.harvard.edu/asdphenotype#Class_665', 'Neurologic Indications', 'http://cbmi.med.harvard.edu/asdphenotype#Class_406', 'Complaints and Indications', 'http://cbmi.med.harvard.edu/asdphenotype#Class_154', 'Medical History', 'http://cbmi.med.harvard.edu/asdphenotype#Class_301', 'Autism Phenotype', None, None)
# ('http://phenomebrowser.net/ontologies/mesh/mesh.owl#G11.561.600.810.444', 'Pain', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G11.561.600.810', 'Sensation', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G11.561.600', 'Nervous System Physiological Processes', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G11.561', 'Nervous System Physiological Phenomena', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G11', 'Musculoskeletal and Neural Physiological Phenomena', None, None)
# ('http://sbmi.uth.tmc.edu/ontology/ochv#C0030193', 'pain', 'http://sbmi.uth.tmc.edu/ontology/ochv#UMLS_Concept', 'UMLS_Concept', 'http://www.w3.org/2004/02/skos/core#Concept', 'Concept', None, None, None, None, None, None)
# ('http://www.semanticweb.org/ontologies/epo.owl#Pain', 'pain', 'http://www.semanticweb.org/ontologies/epo.owl#FunctionalSign', 'functional sign', 'http://www.semanticweb.org/ontologies/epo.owl#SubjectiveSign', 'subjective sign', 'http://www.semanticweb.org/ontologies/epo.owl#Sign', 'sign', 'http://www.semanticweb.org/ontologies/epo.owl#HealthCondition', 'health condition', 'http://www.semanticweb.org/ontologies/2009/3/ontoDPN.owl#OPPIO_d000002', 'maternal state')
# ('https://github.com/sap218/coid/blob/master/coid.owl#COID_00340', 'pain', 'https://github.com/sap218/coid/blob/master/coid.owl#COID_00342', 'acute symptoms', 'https://github.com/sap218/coid/blob/master/coid.owl#COID_00015', 'clinical symptom', None, None, None, None, None, None)
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C91126', 'Have Pain', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173346', 'Pain Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173219', 'Physical Feelings Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173160', 'Feelings Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C91102', 'Clinical or Research Assessment Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20993', 'Research or Clinical Assessment Tool')
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C53837', 'Pain by Anatomic Descriptor, CTCAE', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C53794', 'Adverse Event Associated with Pain', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C53781', 'Adverse Event by CTCAE Category', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C41331', 'Adverse Event', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C36291', 'Finding by Cause', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C3367', 'Finding')
# ('http://www.semanticweb.org/zhenyuzhang/ontologies/2019/8/nonpharmacological-intervention-for-agitation-in-dementia-ontology/Pain', 'Pain', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2019/8/nonpharmacological-intervention-for-agitation-in-dementia-ontology/PhysicalProblem', 'Physical Problem', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2019/8/nonpharmacological-intervention-for-agitation-in-dementia-ontology/IntrapersonalCausativeFactor', 'Intrapersonal Causative Factor', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2019/8/nonpharmacological-intervention-for-agitation-in-dementia-ontology/AgitationCausativeFactor', 'Agitation Causative Factor', None, None, None, None)
# ('http://www.semanticweb.org/zhenyuzhang/ontologies/2021/DREAMDNPTO#Pain', 'Pain', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2021/DREAMDNPTO#Discomfort', 'Discomfort', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2021/DREAMDNPTO#MedicalIllness', 'Medical Illness', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2021/DREAMDNPTO#IntrapersonalCausativeFactor', 'Intrapersonal Causative Factor', 'http://www.semanticweb.org/zhenyuzhang/ontologies/2021/DREAMDNPTO#CausativeFactorOfEmotionalAndMoodDisturbanceInDementia', 'Causative Factor of Emotional and Mood Disturbance in Dementia', None, None)
# ('http://www.semanticweb.org/hll/ontologies/2013/8/untitled-ontology-2#Pain', 'Pain', 'http://www.semanticweb.org/hll/ontologies/2013/8/untitled-ontology-2#Sensory', 'Sensory', 'http://www.semanticweb.org/hll/ontologies/2013/8/untitled-ontology-2#Functional', 'Functional', 'http://www.semanticweb.org/hll/ontologies/2013/8/untitled-ontology-2#Nursing_Diagnoses', 'Nursing_Diagnoses', 'http://www.semanticweb.org/hll/ontologies/2013/8/untitled-ontology-2#CCC_Ontology', 'CCC_Ontology', None, None)
# ('http://www.co-ode.org/ontologies/galen#Pain', 'Pain', 'http://www.co-ode.org/ontologies/galen#ExternalStimulusSensation', 'ExternalStimulusSensation', 'http://www.co-ode.org/ontologies/galen#Sensation', 'Sensation', 'http://www.co-ode.org/ontologies/galen#NAMEDBrainProcess', 'NAMEDBrainProcess', 'http://www.co-ode.org/ontologies/galen#NAMEDPhysiologicalProcess', 'NAMEDPhysiologicalProcess', 'http://www.co-ode.org/ontologies/galen#BodyProcess', 'BodyProcess')
# ('http://purl.jp/bio/4/id/kb0000001532', 'Ache', 'http://purl.jp/bio/4/id/kb0000000261', '疾患プロセス', 'http://purl.jp/bio/4/id/kb0000000214', 'Diseases/Pathology/Symptoms (KNApSAcK)', 'http://purl.jp/bio/4/id/200906041631547545', 'Disease, and Symptom', 'http://purl.jp/bio/4/subject/I', 'General', None, None)
# ('http://purl.bioontology.org/ontology/phenX/170400', 'Pain', 'http://purl.bioontology.org/ontology/phenX/170000', 'Skin, Bone, Muscle and Joint', None, None, None, None, None, None, None, None)
# ('http://purl.obolibrary.org/obo/ogms/OMRE_0000039', 'pain', 'http://purl.obolibrary.org/obo/AERO/_SymptomsSignsTerms', '_SymptomsSignsTerms', 'http://www.ifomis.org/bfo/1.1#Entity', 'Entity', None, None, None, None, None, None)
# ('http://www.shojaee.com/shr/shr.owl#Pain', 'Pain', 'http://www.shojaee.com/shr/shr.owl#Subjective_Genitourinary_Exam_Finding', 'Subjective_Genitourinary_Exam_Finding', 'http://www.shojaee.com/shr/shr.owl#Genitourinary_Examination', 'Genitourinary_Examination', 'http://www.shojaee.com/shr/shr.owl#General_Medical_Exams', 'General_Medical_Exams', None, None, None, None)
# ('http://www.pepathway.org/peo/1.2#Pain', 'Pain', 'http://scai.fraunhofer.de/NDDUO#Symptoms', 'Symptom or sign', 'http://www.ifomis.org/bfo/1.1/snap#Quality', 'quality', 'http://www.ifomis.org/bfo/1.1/snap#SpecificallyDependentContinuant', 'specifically_dependent_continuant', 'http://www.ifomis.org/bfo/1.1/snap#DependentContinuant', 'dependent_continuant', 'http://www.ifomis.org/bfo/1.1/snap#Continuant', 'continuant')
# ('http://sbmi.uth.tmc.edu/ontology/ochv#9185', 'pain', 'http://sbmi.uth.tmc.edu/ontology/ochv#CHV_Concept', 'CHV_Concept', 'http://www.w3.org/2004/02/skos/core#Concept', 'Concept', None, None, None, None, None, None)
# ('http://radlex.org/RID/RID28803', 'pain', 'http://radlex.org/RID/RID39050', 'symptom', 'http://radlex.org/RID/RID34785', 'clinical finding', 'http://radlex.org/RID/RID1', 'RadLex entity', 'http://radlex.org/RID/RID0', 'RadLex ontology entity', None, None)
# ('http://purl.bioontology.org/ontology/MEDDRA/10033371', 'Pain', 'http://purl.bioontology.org/ontology/MEDDRA/10033372', 'Pain and discomfort NEC', 'http://purl.bioontology.org/ontology/MEDDRA/10018073', 'General system disorders NEC', 'http://purl.bioontology.org/ontology/MEDDRA/10018065', 'General disorders and administration site conditions', None, None, None, None)
# ('http://purl.obolibrary.org/obo/CCTO_000107', 'Pain', 'http://purl.obolibrary.org/obo/CCTO_000049', 'Adverse events', 'http://purl.obolibrary.org/obo/CCTO_000043', 'Measure of safety', 'http://purl.obolibrary.org/obo/CCTO_000019', 'Measure of concept', 'http://purl.obolibrary.org/obo/CCTO_000001', 'All', None, None)
# ('http://www.ebi.ac.uk/efo/EFO_0003843', 'pain', 'http://www.ebi.ac.uk/efo/EFO_0003765', 'sign or symptom', 'http://www.ebi.ac.uk/efo/EFO_0000651', 'phenotype', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'material property', 'http://www.ebi.ac.uk/efo/EFO_0000001', 'experimental factor')
# ('http://www.ebi.ac.uk/efo/EFO_0003843', 'pain', 'http://www.ebi.ac.uk/efo/EFO_0003765', 'sign or symptom', 'http://www.ebi.ac.uk/efo/EFO_0000651', 'phenotype', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'material property', 'http://www.ebi.ac.uk/efo/EFO_0000001', 'experimental factor')
# ('http://www.ebi.ac.uk/efo/EFO_0003843', 'pain', 'http://www.ebi.ac.uk/efo/EFO_0003765', 'sign or symptom', 'http://www.ebi.ac.uk/efo/EFO_0000651', 'phenotype', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'material property', 'http://www.ebi.ac.uk/efo/EFO_0000001', 'experimental factor')
# ('http://www.ebi.ac.uk/efo/EFO_0003843', 'pain', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'symptom', 'http://www.ifomis.org/bfo/1.1/snap#Quality', 'quality', 'http://www.ifomis.org/bfo/1.1/snap#SpecificallyDependentContinuant', 'specifically_dependent_continuant', 'http://www.ifomis.org/bfo/1.1/snap#DependentContinuant', 'dependent_continuant', 'http://www.ifomis.org/bfo/1.1/snap#Continuant', 'continuant')
# ('http://purl.obolibrary.org/obo/SYMP_0000099', 'pain', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.org/twc/dpo/ont/Symptom', 'Symptom', 'http://purl.org/twc/dpo/ont/PatientCharacteristic', 'Patient Characteristic', 'http://purl.obolibrary.org/obo/NCIT_C19591', 'Diagnostic Factor', 'http://purl.org/twc/dpo/ont/Thing', 'Thing')
# ('http://purl.obolibrary.org/obo/SYMP_0000099', 'pain', 'http://purl.obolibrary.org/obo/SYMP_0000892', 'sensation perception', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.obolibrary.org/obo/SYMP_0000462', 'symptom', None, None, None, None)
# ('http://purl.obolibrary.org/obo/SYMP_0000099', 'pain', 'http://purl.obolibrary.org/obo/SYMP_0000892', 'sensation perception', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.obolibrary.org/obo/SYMP_0000462', 'symptom', 'http://purl.obolibrary.org/obo/BFO_0000017', 'realizable entity', 'http://purl.obolibrary.org/obo/BFO_0000020', 'specifically dependent continuant')
# ('http://purl.obolibrary.org/obo/SYMP_0000099', 'pain', 'http://purl.obolibrary.org/obo/SYMP_0000892', 'sensation perception', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.obolibrary.org/obo/SYMP_0000462', 'symptom', 'http://purl.bioontology.org/ontology/IDODEN_0000202', 'condition of human host', 'http://purl.obolibrary.org/obo/IDOMAL_0001241', 'condition')
# ('http://purl.obolibrary.org/obo/SYMP_0000099', 'pain', 'http://purl.obolibrary.org/obo/SYMP_0000892', 'sensation perception', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.obolibrary.org/obo/SYMP_0000462', 'symptom', None, None, None, None)
# ('http://purl.obolibrary.org/obo/SYMP_0000099', 'pain', 'http://purl.obolibrary.org/obo/SYMP_0000892', 'sensation perception', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.obolibrary.org/obo/SYMP_0000462', 'symptom', 'http://semanticscience.org/resource/SIO_010056', 'phenotype', 'http://semanticscience.org/resource/SIO_000475', 'biological quality')
# ('http://purl.obolibrary.org/obo/SYMP_0000099', 'pain', 'http://purl.obolibrary.org/obo/SYMP_0000892', 'sensation perception', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.obolibrary.org/obo/SYMP_0000462', 'symptom', 'http://purl.obolibrary.org/obo/BFO_0000001', 'entity', None, None)
# ('http://purl.obolibrary.org/obo/SYMP_0000099', 'pain', 'http://purl.obolibrary.org/obo/SYMP_0000892', 'sensation perception', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.obolibrary.org/obo/OGMS_0000020', 'sintoma', 'http://purl.obolibrary.org/obo/IAO_0000015', 'information carrier', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality')
# ('http://purl.obolibrary.org/obo/SYMP_0000099', 'pain', 'http://purl.obolibrary.org/obo/SYMP_0000892', 'sensation perception', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.obolibrary.org/obo/SYMP_0000462', 'symptom', None, None, None, None)
# ('http://purl.obolibrary.org/obo/SYMP_0000099', 'pain', 'http://purl.obolibrary.org/obo/SYMP_0000892', 'sensation perception', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.obolibrary.org/obo/SYMP_0000462', 'symptom', 'http://purl.obolibrary.org/obo/BFO_0000017', 'realizable entity', 'http://purl.obolibrary.org/obo/BFO_0000020', 'specifically dependent continuant')
# ('http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00639', 'Pain', 'http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00400', 'Nociception', 'http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00681', 'Interoception', 'http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00503', 'Somatosensation', 'http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00418', 'Perception', 'http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00001', 'Cognitive Entity')
# ('http://www.stanford.edu/~coulet/phare.owl#Pain', 'pain', 'http://www.stanford.edu/~coulet/phare.owl#Symptom', 'characteristic', 'http://www.stanford.edu/~coulet/phare.owl#Trait', 'character', 'http://www.stanford.edu/~coulet/phare.owl#Phenotype', 'observation', None, None, None, None)
# ('http://phenomebrowser.net/ontologies/mesh/mesh.owl#D010146', 'Pain', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C10.597.617', 'Pain', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C10.597', 'Neurologic Manifestations', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C10', 'Nervous System Diseases', None, None, None, None)
# ('http://who.int/icf#b280-b289', 'b280-b289. Pain', 'http://who.int/icf#b2', 'b2. CHAPTER 2  SENSORY FUNCTIONS AND PAIN', 'http://who.int/icf#b', 'b. BODY FUNCTIONS', 'http://who.int/icf#ICFCategory', 'ICF Category', 'http://who.int/icd#IdentifiableClass', 'IdentifiableClass', 'http://who.int/icd#Other_classes', 'Other classes')
# ('http://purl.bioontology.org/ontology/RCD/Xa07F', 'Pain', 'http://purl.bioontology.org/ontology/RCD/Xa0yP', 'Pain observations', 'http://purl.bioontology.org/ontology/RCD/Xa05Q', 'Pain and sensation', 'http://purl.bioontology.org/ontology/RCD/X76sV', 'Clinical history and observations', 'http://purl.bioontology.org/ontology/RCD/X76sU', 'History and observations', 'http://purl.bioontology.org/ontology/RCD/XaBVJ', 'Clinical findings')
# ('http://www.cogpo.org/ontologies/COGPO_00165', 'Pain', 'http://www.cogpo.org/ontologies/CogPOver2010.owl#COGPO_00177', 'Explicit Stimulus', 'http://www.cogpo.org/ontologies/CogPOver1.owl#COGPO_00122', 'Stimulus', 'http://www.ifomis.org/bfo/1.1/snap#ObjectAggregate', 'ObjectAggregate', None, None, None, None)
# ('http://www.cogpo.org/ontologies/COGPO_00165', 'Pain', 'http://www.cogpo.org/ontologies/CogPOver1.owl#COGPO_00122', 'Stimulus Type', 'http://purl.obolibrary.org/obo/BFO_0000027', 'object aggregate', 'http://purl.obolibrary.org/obo/BFO_0000040', 'material entity', 'http://purl.obolibrary.org/obo/BFO_0000004', 'independent continuant', 'http://purl.obolibrary.org/obo/BFO_0000002', 'continuant')
# ('http://www.owl-ontologies.com/Ontology1358660052.owl#Pain', 'Pain', 'http://www.owl-ontologies.com/Ontology1358660052.owl#Signs_or_Symptoms', 'Signs_or_Symptoms', 'http://www.owl-ontologies.com/Ontology1358660052.owl#Finding', 'Finding', None, None, None, None, None, None)
# ('http://phenomebrowser.net/ontologies/mesh/mesh.owl#C10.597.617', 'Pain', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C10.597', 'Neurologic Manifestations', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C10', 'Nervous System Diseases', None, None, None, None, None, None)
# ('http://purl.obolibrary.org/obo/PR_Q9W0Y6', 'transient receptor potential cation channel protein painless (fruit fly)', 'http://purl.obolibrary.org/obo/PR_000000001', 'protein', 'http://purl.obolibrary.org/obo/PR_000050567', 'protein-containing material entity', 'http://purl.obolibrary.org/obo/BFO_0000040', 'material entity', None, None, None, None)
# ('http://purl.obolibrary.org/obo/NBO_0000331', 'nociceptive behavior', 'http://purl.obolibrary.org/obo/NBO_0000330', 'cutaneous sensation behavior', 'http://purl.obolibrary.org/obo/NBO_0000327', 'somatic sensation related behavior', 'http://purl.obolibrary.org/obo/NBO_0000751', 'perception behavior by means', 'http://purl.obolibrary.org/obo/NBO_0000308', 'sensation behavior', 'http://purl.obolibrary.org/obo/NBO_0000607', 'cognitive behavior')
# ('http://purl.obolibrary.org/obo/NBO_0000331', 'nociceptive behavior', 'http://purl.obolibrary.org/obo/NBO_0000330', 'cutaneous sensation behavior', 'http://purl.obolibrary.org/obo/NBO_0000607', 'cognitive behavior', 'http://purl.obolibrary.org/obo/NBO_0000313', 'behavior process', 'http://purl.obolibrary.org/obo/GO_0007610', 'behavior', 'http://purl.obolibrary.org/obo/GO_0032501', 'multicellular organismal process')
# ('http://purl.obolibrary.org/obo/NBO_0000331', 'nociceptive behavior', 'http://purl.obolibrary.org/obo/NBO_0000330', 'cutaneous sensation behavior', 'http://purl.obolibrary.org/obo/NBO_0000327', 'somatic sensation related behavior', 'http://purl.obolibrary.org/obo/NBO_0000751', 'perception behavior by means', 'http://purl.obolibrary.org/obo/NBO_0000308', 'sensation behavior', 'http://purl.obolibrary.org/obo/NBO_0000607', 'cognitive behavior')
# ('http://purl.bioontology.org/ontology/CSP/2683-4824', 'pain', 'http://purl.bioontology.org/ontology/CSP/4000-0322', 'sensation', 'http://purl.bioontology.org/ontology/CSP/2483-5397', 'neuropsychology', 'http://purl.bioontology.org/ontology/CSP/2482-6844', 'psychobiology', 'http://purl.bioontology.org/ontology/CSP/2060-1161', 'neuroscience', 'http://purl.bioontology.org/ontology/CSP/0418-4282', 'biology')
# ('http://doe-generated-ontology.com/OntoPneumo#Douleur', 'Pain', 'http://doe-generated-ontology.com/OntoPneumo#SigneFonctionnel', 'functional sign', 'http://doe-generated-ontology.com/OntoPneumo#SigneClinique', 'SigneClinique', 'http://doe-generated-ontology.com/OntoPneumo#Signe', 'sign', 'http://doe-generated-ontology.com/OntoPneumo#EtatDeSante', 'état de sante', 'http://doe-generated-ontology.com/OntoPneumo#EtatPhysique', 'EtatPhysique')
# ('http://www.tcmkg.com/ISPO/ISPO_00001816', 'Pain', 'http://www.tcmkg.com/ISPO/ISPO_00002649', 'Musculoskeletal system symptoms', 'http://www.tcmkg.com/ISPO/ISPO_99999999', 'symptoms', None, None, None, None, None, None)
# ('http://www.semanticweb.org/ontologies/2012/5/Ontology1338526551855.owl#Pain', 'Pain', 'http://www.semanticweb.org/ontologies/2012/5/Ontology1338526551855.owl#All', 'All', 'http://www.semanticweb.org/ontologies/2012/5/Ontology1338526551855.owl#Terms', 'Terms', None, None, None, None, None, None)
# ('http://www.humannervousystem.org/KAnOE/2014/dave86#Pain', 'Pain', 'http://www.humannervousystem.org/KAnOE/2014/dave86#Neurologic_Manifestations', 'Neurologic_Manifestations', 'http://www.humannervousystem.org/KAnOE/2014/dave86#Diseases', 'Diseases', 'http://www.humannervousystem.org/KAnOE/2014/dave86#Condition', 'Condition', 'http://www.humannervousystem.org/KAnOE/2014/dave86#Stative', 'Stative', None, None)
# ('http://purl.bioontology.org/ontology/PDQ/CDR0000041399', 'pain', 'http://purl.bioontology.org/ontology/PDQ/CDR0000041381', 'cancer-related problem/condition', 'http://purl.bioontology.org/ontology/PDQ/CDR0000041060', 'malignant neoplasm', 'http://purl.bioontology.org/ontology/PDQ/CDR0000256086', 'Neoplasm diagnosis', 'http://purl.bioontology.org/ontology/PDQ/CDR0000256085', 'Disease/diagnosis', None, None)
# ('http://www.semanticweb.org/vanessa/ontologies/2012/7/untitled-ontology-33#Pain', 'Pain', 'http://www.semanticweb.org/vanessa/ontologies/2012/7/untitled-ontology-33#Problems', 'Problems', None, None, None, None, None, None, None, None)
# ('http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00675', 'Pain', 'http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00525', 'Somatosensation', 'http://www.cognitiveatlas.org/ontology/cogat.owl#CAO_00001', 'Cognitive Atlas Concept', 'http://www.w3.org/2004/02/skos/core#Concept', 'Concept', None, None, None, None)
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C143725', 'Pain, CTCAE', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C143169', 'General Disorders and Administration Site Conditions, CTCAE', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C143163', 'CTCAE by Body System', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C41331', 'Adverse Event', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C36291', 'Finding by Cause', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C3367', 'Finding')
# ('http://regenbase.org/ontology#RB_0000150', 'pain', 'http://regenbase.org/ontology#RB_0008003', 'condition', 'http://regenbase.org/ontology#RB_0000484', 'quality', 'http://regenbase.org/ontology#RB_0000483', 'attribute', None, None, None, None)
# ('http://www.semanticweb.org/rjyy/ontologies/2015/5/ESSO#Pain', 'Pain', 'http://www.semanticweb.org/rjyy/ontologies/2015/5/ESSO#Somatosensory_Sensation_Abnormal', 'Somatosensory_Sensation_Abnormal', 'http://www.semanticweb.org/rjyy/ontologies/2015/5/ESSO#Somatosensory_Sensation', 'Somatosensory_Sensation', 'http://www.semanticweb.org/rjyy/ontologies/2015/5/ESSO#Blume_2001_II_2.2.1.1_Somatosensory', 'Blume_2001_II_2.2.1.1_Somatosensory', 'http://www.semanticweb.org/rjyy/ontologies/2015/5/ESSO#Blume_2001_II_2.2.1_Elementary', 'Blume_2001_II_2.2.1_Elementary', 'http://www.semanticweb.org/rjyy/ontologies/2015/5/ESSO#Blume_2001_II_2.2_Sensory', 'Blume_2001_II_2.2_Sensory')
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C104600', 'Frequency of Pain', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173358', 'Frequency Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C91102', 'Clinical or Research Assessment Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20993', 'Research or Clinical Assessment Tool', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C18742', 'Diagnostic or Prognostic Test', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C18020', 'Diagnostic Procedure')
# ('http://www.icn.ch/icnp#Pain', 'Pain', 'http://www.icn.ch/icnp#NegativePerception', 'NegativePerception', 'http://www.icn.ch/icnp#NegativeNervousSystemProcess', 'NegativeNervousSystemProcess', 'http://www.icn.ch/icnp#NervousSystemProcess', 'NervousSystemProcess', 'http://www.icn.ch/icnp#BodyProcess', 'BodyProcess', 'http://www.icn.ch/icnp#Process', 'Process')
# ('http://phenomebrowser.net/ontologies/mesh/mesh.owl#F02.830.816.444', 'Pain', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#F02.830.816', 'Sensation', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#F02.830', 'Psychophysiology', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#F02', 'Psychological Phenomena and Processes', None, None, None, None)
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C125299', 'Usual Severity Pain', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173346', 'Pain Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173219', 'Physical Feelings Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173160', 'Feelings Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C91102', 'Clinical or Research Assessment Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20993', 'Research or Clinical Assessment Tool')
# ('http://purl.org/twc/dpo/ont/Pain', 'Pain', 'http://purl.obolibrary.org/obo/SYMP_0000480', 'nervous system symptom', 'http://purl.org/twc/dpo/ont/Symptom', 'Symptom', 'http://purl.org/twc/dpo/ont/PatientCharacteristic', 'Patient Characteristic', 'http://purl.obolibrary.org/obo/NCIT_C19591', 'Diagnostic Factor', 'http://purl.org/twc/dpo/ont/Thing', 'Thing')
# ('http://phenomebrowser.net/ontologies/mesh/mesh.owl#C23.888.592.612', 'Pain', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C23.888.592', 'Neurologic Manifestations', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C23.888', 'Signs and Symptoms', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C23', 'Pathological Conditions, Signs and Symptoms', None, None, None, None)
# ('http://purl.bioontology.org/ontology/WHO/0730', 'PAIN', 'http://purl.bioontology.org/ontology/WHO/1810', 'ADENOMA ADRENAL', 'http://purl.bioontology.org/ontology/WHO/0900', 'IMMUNOGLOBULINS DECREASED', 'http://purl.bioontology.org/ontology/WHO/1220', 'ANORGASMIA', 'http://purl.bioontology.org/ontology/WHO/1420', 'RETINAL OEDEMA', 'http://purl.bioontology.org/ontology/WHO/0431', 'AV BLOCK')
# ('http://purl.bioontology.org/ontology/OMIM/MTHU033713', 'Pain', 'http://purl.bioontology.org/ontology/OMIM/MTHU000058', 'Central nervous system', 'http://purl.bioontology.org/ontology/OMIM/MTHU000057', 'NEUROLOGIC', None, None, None, None, None, None)
# ('http://purl.obolibrary.org/obo/SCDO_0000851', 'Pain', 'http://purl.obolibrary.org/obo/HP_0025142', 'Constitutional Symptom', 'http://purl.obolibrary.org/obo/HP_0000118', 'Abnormal Phenotype', 'http://purl.obolibrary.org/obo/OGMS_0000023', 'Phenotype', 'http://purl.obolibrary.org/obo/SCDO_0001000', 'SCDO', None, None)
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C3303', 'Pain', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C4876', 'Symptom', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100104', 'Sign or Symptom', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C3367', 'Finding', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C7057', 'Disease, Disorder or Finding', None, None)
# ('http://purl.obolibrary.org/obo/MFOEM_000203', 'pain', 'http://purl.obolibrary.org/obo/MFOEM_000006', 'subjective affective feeling', 'http://purl.obolibrary.org/obo/MFOEM_000195', 'affective process', 'http://purl.obolibrary.org/obo/MF_0000020', 'mental process', 'http://purl.obolibrary.org/obo/OGMS_0000060', 'bodily process', 'http://purl.obolibrary.org/obo/BFO_0000015', 'process')
# ('http://purl.bioontology.org/ontology/MEDLINEPLUS/C0030193', 'Pain', 'http://purl.bioontology.org/ontology/MEDLINEPLUS/C2362500', 'Brain and Nerves', None, None, None, None, None, None, None, None)
# ('http://ontology.apa.org/apaonto/termsonlyOUT%20(5).owl#Pain', 'Pain', 'http://www.semanticweb.org/ontologies/2015/0/disorderscluster.owl#Symptomology', 'Symptomology', None, None, None, None, None, None, None, None)
# ('http://ontology.apa.org/apaonto/termsonlyOUT%20(5).owl#Pain', 'Pain', 'http://www.semanticweb.org/ontologies/2015/0/apaneurocluster.owl#NeurologicalDisorders', 'NeurologicalDisorders', None, None, None, None, None, None, None, None)
# ('http://uri.neuinfo.org/nif/nifstd/birnlex_1814', 'Pain sensation', 'http://uri.neuinfo.org/nif/nifstd/birnlex_1822', 'Somatic sensation', 'http://uri.neuinfo.org/nif/nifstd/birnlex_1825', 'Sensory perception', 'http://purl.obolibrary.org/obo/BFO_0000016', 'disposition', 'http://purl.obolibrary.org/obo/BFO_0000017', 'realizable entity', 'http://purl.obolibrary.org/obo/BFO_0000020', 'specifically dependent continuant')
# ('http://www.mskcc.org/ontologies/2013/03/sae.owl#Pain', 'Pain', 'http://www.mskcc.org/ontologies/2013/03/sae.owl#Categories', 'Categories', None, None, None, None, None, None, None, None)
# ('http://purl.jp/bio/11/csso/CSSO_000176', 'Pain', 'http://purl.jp/bio/11/csso/CSSO_000022', 'General symptom', 'http://purl.jp/bio/11/csso/CSSO_000010', 'Clinical signs and symptoms', None, None, None, None, None, None)
# ('http://purl.obolibrary.org/obo/TRAK_0000196', 'pain', 'http://purl.obolibrary.org/obo/TRAK_0000092', 'clinical manifestation', 'http://purl.obolibrary.org/obo/TRAK_0000133', 'quality', 'http://purl.obolibrary.org/obo/TRAK_0000409', 'continuant', 'http://purl.obolibrary.org/obo/TRAK_0000001', 'entity', None, None)
# ('http://phenomebrowser.net/ontologies/mesh/mesh.owl#C23.888.646', 'Pain', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C23.888', 'Signs and Symptoms', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C23', 'Pathological Conditions, Signs and Symptoms', None, None, None, None, None, None)
# ('http://purl.bioontology.org/ontology/CST/PAIN', 'PAIN', 'http://purl.bioontology.org/ontology/CST/GENSYMPTOMS', 'SYMPTOMS', 'http://purl.bioontology.org/ontology/CST/GEN', 'NONSPECIFIC DISORDERS', None, None, None, None, None, None)
# ('http://purl.obolibrary.org/obo/icdo.owl#ICDO_0000446', 'pain', 'http://purl.obolibrary.org/obo/icdo.owl#ICDO_0000408', 'general symptoms', 'http://purl.obolibrary.org/obo/ICDO_0000364', 'symptoms, signs and abnormal clinical and laboratory findings', 'http://purl.obolibrary.org/obo/ICDO_0000001', '病程', 'http://purl.obolibrary.org/obo/OGMS_0000061', 'pathological bodily process', 'http://purl.obolibrary.org/obo/OGMS_0000060', 'bodily process')
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/ctcae5.owl#C143725', 'Pain', 'http://ncicb.nci.nih.gov/xml/owl/EVS/ctcae5.owl#C143169', 'General Disorders and Administration Site Conditions', 'http://ncicb.nci.nih.gov/xml/owl/EVS/ctcae5.owl#C143163', 'Adverse Event by System Organ Class', None, None, None, None, None, None)
# ('http://purl.obolibrary.org/obo/MESH_D010146', 'Pain', 'http://purl.obolibrary.org/obo/MESH_D012677', 'Sensation', 'http://purl.obolibrary.org/obo/MESH_D011603', 'Psychophysiology', 'http://purl.obolibrary.org/obo/MESH_D010827', 'Physiology', 'http://purl.obolibrary.org/obo/MESH_D001690', 'Biological Science Disciplines', 'http://purl.obolibrary.org/obo/MESH_D010811', 'Natural Science Disciplines')
# ('http://purl.obolibrary.org/obo/HP_0012531', 'Pain', 'http://purl.obolibrary.org/obo/HP_0025142', 'Constitutional symptom', 'http://purl.obolibrary.org/obo/HP_0000118', 'Phenotypic abnormality', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'specifically dependent continuant', 'http://purl.obolibrary.org/obo/BFO_0000002', 'continuant')
# ('http://purl.obolibrary.org/obo/HP_0012531', 'Pain', 'http://purl.obolibrary.org/obo/HP_0025142', 'Constitutional symptom', 'http://purl.obolibrary.org/obo/HP_0000118', 'Phenotypic abnormality', 'http://purl.obolibrary.org/obo/HP_0000001', 'All', None, None, None, None)
# ('http://purl.obolibrary.org/obo/HP_0012531', 'Pain', 'http://purl.obolibrary.org/obo/HP_0000118', 'Phenotypic abnormality', 'http://purl.obolibrary.org/obo/MER_0000001', 'melanoma ontology', None, None, None, None, None, None)
# ('http://purl.obolibrary.org/obo/HP_0012531', 'Pain', 'http://purl.obolibrary.org/obo/HP_0025142', 'Constitutional symptom', 'http://purl.obolibrary.org/obo/HP_0000118', 'Phenotypic abnormality', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'specifically dependent continuant', 'http://purl.obolibrary.org/obo/BFO_0000002', 'continuant')
# ('http://purl.obolibrary.org/obo/HP_0012531', 'Pain', 'http://purl.obolibrary.org/obo/HP_0025142', 'Constitutional symptom', 'http://purl.obolibrary.org/obo/HP_0000118', 'Phenotypic abnormality', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'specifically dependent continuant', 'http://purl.obolibrary.org/obo/BFO_0000002', 'continuant')
# ('http://purl.obolibrary.org/obo/HP_0012531', 'Pain', 'http://purl.obolibrary.org/obo/HP_0025142', 'Constitutional symptom', 'http://purl.obolibrary.org/obo/HP_0000118', 'Phenotypic abnormality', 'http://purl.obolibrary.org/obo/UPHENO_0001001', 'UPHENO_0001001', None, None, None, None)
# ('http://purl.obolibrary.org/obo/HP_0012531', 'Pain', 'http://purl.obolibrary.org/obo/HP_0025142', 'Constitutional symptom', 'http://purl.obolibrary.org/obo/HP_0000118', 'Phenotypic abnormality', 'http://purl.obolibrary.org/obo/HP_0000001', 'All', None, None, None, None)
# ('http://purl.obolibrary.org/obo/HP_0012531', 'Pain', 'http://purl.obolibrary.org/obo/HP_0025142', 'Constitutional symptom', 'http://purl.obolibrary.org/obo/HP_0000118', 'Phenotypic abnormality', 'http://purl.obolibrary.org/obo/BFO_0000019', 'quality', 'http://purl.obolibrary.org/obo/BFO_0000020', 'specifically dependent continuant', 'http://purl.obolibrary.org/obo/BFO_0000002', 'continuant')
# ('http://www.limics.fr/ontologies/ontoparonmed#Douleur', 'Pain function', 'http://www.limics.fr/ontologies/ontoparonmed#SigneClinique', 'clinical sign', 'http://www.limics.fr/ontologies/ontoparonmed#SigneEtSymptome', 'signs and symptoms', 'http://www.limics.fr/ontologies/ontoparonmed#EtatDeSante', 'health status', 'http://www.limics.fr/ontologies/ontoparonnoy#Etat', 'status', 'http://www.limics.fr/ontologies/menelastop#ObjetIntentionnel', 'intentional object')
# ('http://purl.bioontology.org/ontology/ICD9CM/338-338.99', 'PAIN', 'http://purl.bioontology.org/ontology/ICD9CM/320-389.99', 'DISEASES OF THE NERVOUS SYSTEM AND SENSE ORGANS', 'http://purl.bioontology.org/ontology/ICD9CM/001-999.99', 'DISEASES AND INJURIES', None, None, None, None, None, None)
# ('http://www.semanticweb.org/danielhier/ontologies/2019/3/untitled-ontology-57/pain', 'pain', 'http://www.semanticweb.org/danielhier/ontologies/2019/3/untitled-ontology-57/symptom', 'symptom', 'http://www.semanticweb.org/danielhier/ontologies/2019/3/untitled-ontology-57#sign', 'sign', None, None, None, None, None, None)
# ('http://www.semanticweb.org/danielhier/ontologies/2019/3/untitled-ontology-57/pain', 'pain', 'http://www.semanticweb.org/danielhier/ontologies/2019/3/untitled-ontology-57/symptom', 'symptom', 'http://www.semanticweb.org/danielhier/ontologies/2019/3/untitled-ontology-57/interictal_finding', 'interictal_finding', None, None, None, None, None, None)
# ('http://purl.obolibrary.org/obo/NCIT_C3303', 'Pain', 'http://purl.obolibrary.org/obo/NCIT_C7057', 'Disease, Disorder or Finding', 'http://purl.org/twc/dpo/ont/ExternalClass', 'External Class', None, None, None, None, None, None)
# ('http://purl.obolibrary.org/obo/NCIT_C3303', 'Pain', 'http://purl.obolibrary.org/obo/NCIT_C4876', 'Symptom', 'http://purl.obolibrary.org/obo/NCIT_C100104', 'Sign or Symptom', 'http://purl.obolibrary.org/obo/NCIT_C3367', 'Finding', 'http://purl.obolibrary.org/obo/NCIT_C7057', 'Disease, Disorder or Finding', None, None)
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C141521', 'Feel Pain', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C91126', 'Have Pain', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173346', 'Pain Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173219', 'Physical Feelings Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173160', 'Feelings Question', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C91102', 'Clinical or Research Assessment Question')
# ('http://www.phoc.org.cn/pmo/class/PMO_00014074', 'Pain', 'http://www.phoc.org.cn/pmo/class/PMO_00014047', 'Constitutional Symptom', 'http://www.phoc.org.cn/pmo/class/PMO_00000866', 'Phenotypic Abnormality', None, None, None, None, None, None)
# ...
# ('http://purl.bioontology.org/ontology/MESH/D005528', 'Foot', 'http://purl.bioontology.org/ontology/MESH/D035002', 'Lower Extremity', 'http://purl.bioontology.org/ontology/MESH/D005121', 'Extremities', 'http://purl.bioontology.org/ontology/MESH/D001829', 'Body Regions', None, None, None, None)
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C191656', 'Pregnant Subject', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C41189', 'Study Subject', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C79916', 'Investigative Subject', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C48910', 'Subject', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20181', 'Conceptual Entity', None, None)
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#Pregnancy', 'Pregnancy', 'http://scai.fraunhofer.de/CSEO#CSEO_03000020', 'Finding', 'http://www.ifomis.org/snap#Disposition', 'disposition', 'http://www.ifomis.org/snap#RealizableEntity', 'realizable_entity', 'http://www.ifomis.org/snap#SpecificallyDependentContinuant', 'specifically_dependent_continuant', 'http://www.ifomis.org/snap#DependentContinuant', 'dependent_continuant')
# ('http://www.ebi.ac.uk/efo/EFO_0002950', 'pregnancy', 'http://purl.obolibrary.org/obo/GO_0000003', 'reproduction', 'http://purl.obolibrary.org/obo/GO_0008150', 'biological_process', 'http://purl.obolibrary.org/obo/BFO_0000015', 'process', 'http://www.ebi.ac.uk/efo/EFO_0000001', 'experimental factor', None, None)
# ('http://www.ebi.ac.uk/efo/EFO_0002950', 'pregnancy', 'http://purl.obolibrary.org/obo/GO_0000003', 'reproduction', 'http://purl.obolibrary.org/obo/GO_0008150', 'biological_process', 'http://purl.obolibrary.org/obo/BFO_0000015', 'process', 'http://www.ebi.ac.uk/efo/EFO_0000001', 'experimental factor', None, None)
# ('http://www.ebi.ac.uk/efo/EFO_0002950', 'pregnancy', 'http://purl.obolibrary.org/obo/GO_0000003', 'reproduction', 'http://purl.obolibrary.org/obo/GO_0008150', 'biological_process', 'http://purl.obolibrary.org/obo/BFO_0000015', 'process', 'http://www.ebi.ac.uk/efo/EFO_0000001', 'experimental factor', None, None)
# ('http://purl.obolibrary.org/obo/OMIT_0012209', 'Pregnancy', 'http://purl.obolibrary.org/obo/OMIT_0013022', 'Reproduction', 'http://purl.obolibrary.org/obo/OMIT_0026442', 'Reproductive Physiological Processes', 'http://purl.obolibrary.org/obo/OMIT_0026441', 'Reproductive Physiological Phenomena', 'http://purl.obolibrary.org/obo/OMIT_0013025', 'Reproductive and Urinary Physiological Phenomena', 'http://purl.obolibrary.org/obo/OMIT_0001007', 'Phenomena and Processes Category')
# ('http://purl.bioontology.org/ontology/CSP/2400-8114', 'pregnancy', 'http://purl.bioontology.org/ontology/CSP/2586-6130', 'reproduction', 'http://purl.bioontology.org/ontology/CSP/0418-4826', 'life cycle', 'http://purl.bioontology.org/ontology/CSP/1354-3663', 'growth/development', 'http://purl.bioontology.org/ontology/CSP/0418-4282', 'biology', None, None)
# ('http://purl.bioontology.org/ontology/MESH/D011247', 'Pregnancy', 'http://purl.bioontology.org/ontology/MESH/D012098', 'Reproduction', 'http://purl.bioontology.org/ontology/MESH/D055703', 'Reproductive Physiological Phenomena', 'http://purl.bioontology.org/ontology/MESH/D012101', 'Reproductive and Urinary Physiological Phenomena', None, None, None, None)
# ('http://purl.bioontology.org/ontology/MEDDRA/10036556', 'Pregnancy', 'http://purl.bioontology.org/ontology/MEDDRA/10029772', 'Normal pregnancy, labour and delivery', 'http://purl.bioontology.org/ontology/MEDDRA/10010273', 'Pregnancy, labour, delivery and postpartum conditions', 'http://purl.bioontology.org/ontology/MEDDRA/10036585', 'Pregnancy, puerperium and perinatal conditions', None, None, None, None)
# ('http://purl.org/twc/HHEAR_00489', 'Pregnancy', 'http://purl.org/twc/HHEAR_00507', 'From Conception', 'http://purl.org/twc/HHEAR_00508', 'Relative Time', 'http://semanticscience.org/resource/SIO_000391', 'time measurement', 'http://semanticscience.org/resource/SIO_000258', 'dimensional quantity', 'http://semanticscience.org/resource/SIO_000052', 'quantity')
# ('http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C25742', 'Pregnancy', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C21173', 'Reproductive Process', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C19988', 'Organismal Process', 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C17828', 'Biological Process', None, None, None, None)
# ('http://www.semanticweb.org/ontologies/2012/0/Ontology1325521724189.owl#Pregnancy', 'Pregnancy', 'http://www.semanticweb.org/ontologies/2012/0/Ontology1325521724189.owl#Exclusion_criteria', 'Exclusion criteria', 'http://www.semanticweb.org/ontologies/2012/0/Ontology1325521724189.owl#Recruitment_criteria', 'Recruitment criteria', 'http://www.co-ode.org/ontologies/ont.owl#Recruitment_of_patients', 'Patient recruitment', 'http://www.semanticweb.org/ontologies/2012/0/Ontology1325521724189.owl#Study_Conduct_Sub-Domain', 'Conduct of the study', 'http://www.co-ode.org/ontologies/ont.owl#Clinical_trial', 'Clinical trial')
# ('http://purl.jp/bio/4/id/200906033179058270', 'Pregnancy', 'http://purl.jp/bio/4/id/200906067736606163', 'reproduction (biology)', 'http://purl.jp/bio/4/subject/System_cat', 'Biological phenomenon, process, and state', 'http://purl.jp/bio/4/subject/IA07', 'Phenomena', 'http://purl.jp/bio/4/subject/I', 'General', None, None)
# ('http://www.pepathway.org/peo/1.2#Pregnancy', 'Pregnancy', 'http://www.pepathway.org/peo/1.2#Basic_attribute_on_pregnancy', 'Basic attribute on pregnancy', 'http://www.ifomis.org/bfo/1.1/snap#Quality', 'quality', 'http://www.ifomis.org/bfo/1.1/snap#SpecificallyDependentContinuant', 'specifically_dependent_continuant', 'http://www.ifomis.org/bfo/1.1/snap#DependentContinuant', 'dependent_continuant', 'http://www.ifomis.org/bfo/1.1/snap#Continuant', 'continuant')
# ('http://purl.obolibrary.org/obo/NCIT_C25742', 'Pregnancy', 'http://purl.obolibrary.org/obo/NCIT_C21173', 'Reproductive Process', 'http://purl.obolibrary.org/obo/NCIT_C19988', 'Organismal Process', 'http://purl.obolibrary.org/obo/NCIT_C17828', 'Biological Process', None, None, None, None)
# ('http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686.785.760.769', 'Pregnancy', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686.785.760', 'Reproduction', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686.785', 'Reproductive Physiological Processes', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686', 'Reproductive Physiological Phenomena', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08', 'Reproductive and Urinary Physiological Phenomena', None, None)
# ('http://www.ifomis.org/acgt/1.0#Pregnancy', 'Pregnancy', 'http://www.ifomis.org/acgt/1.0#OrganismalProcess', 'OrganismalProcess', 'http://www.ifomis.org/acgt/1.0#NaturalProcess', 'NaturalProcess', 'http://www.ifomis.org/bfo/1.1/span#Process', 'process', 'http://www.ifomis.org/bfo/1.1/span#ProcessualEntity', 'processual_entity', 'http://www.ifomis.org/bfo/1.1/span#Occurrent', 'occurrent')
# ('http://purl.obolibrary.org/obo/XCO_0000412', 'gestation', 'http://purl.obolibrary.org/obo/XCO_0000411', 'reproduction condition', 'http://purl.obolibrary.org/obo/XCO_0000000', 'experimental condition', None, None, None, None, None, None)
# ('http://www.owl-ontologies.com/Ontology1358660052.owl#Pregnancy', 'Pregnancy', 'http://www.owl-ontologies.com/Ontology1358660052.owl#Reproductive_Process', 'Reproductive_Process', 'http://www.owl-ontologies.com/Ontology1358660052.owl#Organismal_Process', 'Organismal_Process', None, None, None, None, None, None)
# ('http://purl.bioontology.org/ontology/SNOMEDCT/289908002', 'Pregnancy', 'http://purl.bioontology.org/ontology/SNOMEDCT/289907007', 'Female genital tract functions', 'http://purl.bioontology.org/ontology/SNOMEDCT/76859005', 'Sexual function', 'http://purl.bioontology.org/ontology/SNOMEDCT/246464006', 'Function', 'http://purl.bioontology.org/ontology/SNOMEDCT/363787002', 'Observable entity', None, None)
# ('http://mental-ontology.com/mental_health_bfo.owl#Pregnancy', 'Pregnancy', 'http://purl.obolibrary.org/obo/BFO_0000016', 'disposition', 'http://purl.obolibrary.org/obo/BFO_0000017', 'realizable entity', 'http://purl.obolibrary.org/obo/BFO_0000020', 'specifically dependent continuant', 'http://purl.obolibrary.org/obo/BFO_0000002', 'continuant', 'http://purl.obolibrary.org/obo/BFO_0000001', 'entity')
# ('http://purl.jp/bio/4/id/kb0000001620', 'Pregnancy', 'http://purl.jp/bio/4/id/kb0000000116', 'Biological process (KNApSAcK)', 'http://purl.jp/bio/4/subject/System_cat', 'Biological phenomenon, process, and state', 'http://purl.jp/bio/4/subject/IA07', 'Phenomena', 'http://purl.jp/bio/4/subject/I', 'General', None, None)
# ('http://www.semanticweb.org/administrator/ontologies/2022/0/untitled-ontology-34#OWLClassac85ad9b_de81_4bcf_b9fd_6ea4b49a2e69', 'Pregnancy', 'http://www.semanticweb.org//Childbearing-ageWomenwithEpilepsyOntology#OWLClassa08bc63f_763f_4752_bdfb_b7bd5e7175e4', 'Treatment for women of childbearing age', 'http://www.semanticweb.org//Childbearing-ageWomenwithEpilepsyOntology#OWLClass7aa094f9_1233_480b_b8b2_466e1c3e8d44', 'Treatment Process', 'http://www.semanticweb.org//Childbearing-ageWomenwithEpilepsyOntology#OWLClass429e5ce3_a189_415e_a957_198fc3277e7b', 'Process', 'http://www.semanticweb.org//Childbearing-ageWomenwithEpilepsyOntology#OWLClasscbc7b126_0b2f_4678_b2a4_7c31c7d8e74c', 'Occurent', None, None)
# ('http://bmi.utah.edu/ontologies/hfontology/C0032961', 'Pregnancy', 'http://bmi.utah.edu/ontologies/hfontology/Causes_risk_factors', 'Causes_risk_factors', None, None, None, None, None, None, None, None)
# ('http://purl.bioontology.org/ontology/NDFRT/N0000010195', 'Pregnancy [Disease/Finding]', 'http://purl.bioontology.org/ontology/NDFRT/N0000010197', 'Physiologic States [Disease/Finding]', 'http://purl.bioontology.org/ontology/NDFRT/N0000000004', 'Diseases, Manifestations or Physiologic States [Disease/Finding]', 'http://purl.bioontology.org/ontology/NDFRT/NOCODE', 'National Drug File - Reference Terminology', None, None, None, None)
# ('http://hadatac.org/ont/chear#Pregnancy', 'Pregnancy', 'http://hadatac.org/ont/chear#PregnancyCharacteristic', 'Pregnancy Characteristic', 'http://hadatac.org/ont/hasco/StudyIndicator', 'Study Indicator', 'http://hadatac.org/ont/hasco/Indicator', 'Indicator', None, None, None, None)
# ('http://www.semanticweb.org/luyu/ontologies/2021/3/pregnancy_information_needs_ontology#Pregnancy', 'Pregnancy', 'http://www.semanticweb.org/luyu/ontologies/2021/3/pregnancy_information_needs_ontology#Common_Themes', 'Common_Themes', None, None, None, None, None, None, None, None)
# ('http://purl.bioontology.org/ontology/RCD/Xa4eG', 'Pregnancy', 'http://purl.bioontology.org/ontology/RCD/Xa4eF', 'Female genital tract functions', 'http://purl.bioontology.org/ontology/RCD/X76Ls', 'Sexual function', 'http://purl.bioontology.org/ontology/RCD/Xa8J6', 'Urogenital functions', 'http://purl.bioontology.org/ontology/RCD/Xa26Z', 'Physiological functions and activities', 'http://purl.bioontology.org/ontology/RCD/X75Wq', 'Functions')
# ('http://www.co-ode.org/ontologies/galen#Pregnancy', 'Pregnancy', 'http://www.co-ode.org/ontologies/galen#NAMEDReproductiveProcess', 'NAMEDReproductiveProcess', 'http://www.co-ode.org/ontologies/galen#ReproductiveProcess', 'ReproductiveProcess', 'http://www.co-ode.org/ontologies/galen#NAMEDPhysiologicalProcess', 'NAMEDPhysiologicalProcess', 'http://www.co-ode.org/ontologies/galen#BodyProcess', 'BodyProcess', 'http://www.co-ode.org/ontologies/galen#BiologicalProcess', 'BiologicalProcess')
# ('http://purl.bioontology.org/ontology/WHO/0663', 'PREGNANCY UNINTENDED', 'http://purl.bioontology.org/ontology/WHO/1420', 'RETINAL OEDEMA', 'http://purl.bioontology.org/ontology/WHO/0431', 'AV BLOCK', 'http://purl.bioontology.org/ontology/WHO/1030', 'ASPIRATION', 'http://purl.bioontology.org/ontology/WHO/1100', 'THYROID ADENOMA', 'http://purl.bioontology.org/ontology/WHO/0900', 'IMMUNOGLOBULINS DECREASED')
# ('http://purl.bioontology.org/ontology/SNOMEDCT/77386006', 'Pregnancy', 'http://purl.bioontology.org/ontology/SNOMEDCT/118185001', 'Finding related to pregnancy', 'http://purl.bioontology.org/ontology/SNOMEDCT/248982007', 'Pregnancy, childbirth and puerperium finding', 'http://purl.bioontology.org/ontology/SNOMEDCT/404684003', 'Clinical finding', None, None, None, None)
# ('http://sbmi.uth.tmc.edu/ontology/ochv#C0032961', 'pregnancy', 'http://sbmi.uth.tmc.edu/ontology/ochv#UMLS_Concept', 'UMLS_Concept', 'http://www.w3.org/2004/02/skos/core#Concept', 'Concept', None, None, None, None, None, None)
# ('http://sbmi.uth.tmc.edu/ontology/ochv#10047', 'pregnancy', 'http://sbmi.uth.tmc.edu/ontology/ochv#CHV_Concept', 'CHV_Concept', 'http://www.w3.org/2004/02/skos/core#Concept', 'Concept', None, None, None, None, None, None)
# ('http://www.semanticweb.org/ontologies/chronic-diease-patient-education-ontology#Pregnancy', 'Pregnancy', 'http://www.semanticweb.org/ontologies/chronic-diease-patient-education-ontology#Demographic', 'Demographic', None, None, None, None, None, None, None, None)
# ('http://www.projecthalo.com/aura#Pregnancy', 'Pregnancy', 'http://www.projecthalo.com/aura#Condition', 'Condition', 'http://www.projecthalo.com/aura#State', 'State', 'http://www.projecthalo.com/aura#Event', 'Event', None, None, None, None)
# ('http://phenomebrowser.net/ontologies/mesh/mesh.owl#D011247', 'Pregnancy', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686.785.760.769', 'Pregnancy', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686.785.760', 'Reproduction', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686.785', 'Reproductive Physiological Processes', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08.686', 'Reproductive Physiological Phenomena', 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#G08', 'Reproductive and Urinary Physiological Phenomena')
# ('http://purl.bioontology.org/ontology/MEDLINEPLUS/C0032961', 'Pregnancy', 'http://purl.bioontology.org/ontology/MEDLINEPLUS/C0043210', 'Women', None, None, None, None, None, None, None, None)
# ('http://www.icn.ch/icnp#Pregnancy', 'Pregnancy', 'http://www.icn.ch/icnp#ReproductiveSystemProcess', 'ReproductiveSystemProcess', 'http://www.icn.ch/icnp#BodyProcess', 'BodyProcess', 'http://www.icn.ch/icnp#Process', 'Process', 'http://www.icn.ch/icnp#Phenomenon', 'Phenomenon', None, None)
# ('http://radlex.org/RID/RID4941', 'pregnancy', 'http://radlex.org/RID/RID36008', 'benign finding', 'http://radlex.org/RID/RID34785', 'clinical finding', 'http://radlex.org/RID/RID1', 'RadLex entity', 'http://radlex.org/RID/RID0', 'RadLex ontology entity', None, None)
# ('http://www.semanticweb.org/ontologies/epo.owl#OPPIO_d000100', 'pregnancy', 'http://www.semanticweb.org/ontologies/epo.owl#OPPIO_c000016', 'internal state', 'http://www.semanticweb.org/ontologies/2009/3/ontoDPN.owl#OPPIO_d000002', 'maternal state', 'http://www.semanticweb.org/ontologies/2009/3/ontoDPN.owl#OPPIO_d000000', 'human being state', 'http://www.semanticweb.org/ontologies/2009/3/ontoDPN.owl#PhysicalState', 'physical state', 'http://www.semanticweb.org/ontologies/2009/3/ontoDPN.owl#StateOfPhysicalObject', 'state of physical object')
# ('http://bioportal/bioontology.org/ontologies/HIVO0004#OWLClass_00000010680792664081', 'Pregnancy', 'http://bioportal/bioontology.org/ontologies/HIVO0004#OWLClass_00000010612308063594', 'BehaviourOfWoman', 'http://www.semanticweb.org/owner/ontologies/2014/2/HIVandAIDS.owl#OWLClass_00000006879338175173', 'MovementOrBehaviourOfWholeHumanBodyOrItsPart', 'http://bioportal/bioontology.org/ontologies/HIVO0004#OWLClass_20e49202_cc8f_43bc_aa5d_c1aaf539fcd8', 'BehaviourOrMovementOfMacro-MicroStructuralLevelOfBiology', 'http://www.semanticweb.org/owner/ontologies/2014/2/HIVandAIDS.owl#OWLClass_00000003851235205731', 'BiologicalProcessOrBehaviourOrMovement', 'http://www.semanticweb.org/owner/ontologies/2014/2/HIVandAIDS.owl#OWLClass_00000011013119714377', 'BiologicalFeatureOrBehaviourOrMovementOrFunctionOrProcess')

# %%
print(cursor.execute("SELECT count(*) FROM hierarchyMedicalConcepts").fetchall())
# Out:
# [(213,)]
