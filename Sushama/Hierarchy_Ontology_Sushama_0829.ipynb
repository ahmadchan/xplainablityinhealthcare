# %% [markdown]
# # NESTED Dictionary creation for Bioportal Onotologies Generated data about Hierarchies.
#
# **Example Input:**
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/G-A425
# 	prefLabel: Malignant
# 	ontology: https://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 1
# 	to: 9
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G-A200
# 			prefLabel: Positive
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G-A000
# 			prefLabel: Severity of illness, NOS
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/G
# 			prefLabel: GENERAL LINKAGE/MODIFIERS
# 			ontology: https://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 3
#
# **Example output in Nested Dictionary Form:**
# hierarchies = {
#     1: {
#         'hiearachy_1': 'Positive',
#         'hiearachy_2': 'Severity of illness, NOS',
#         'hiearachy_3': 'GENERAL LINKAGE/MODIFIERS'
#         'match_type': 'PREF'
#     },
#     2: {
#         'hiearachy_1': 'Positive',
#         'hiearachy_2': 'Severity of illness',
#         'hiearachy_3': 'GENERAL LINKAGE/MODIFIERS'
#         'match_type': 'Synon'
#     }
# }
#
# Things to consider:
# 1. Data should be in English language, translate or remove any content out of english.
# 2. Try to remove repetatives.
# 3. Python dictionary default size may exceed. Try using json format and create file instead.

# %%
import urllib.request, urllib.error, urllib.parse
import json
import os
from pprint import pprint

REST_URL = "http://data.bioontology.org"
API_KEY = "396993d0-4ce2-4123-93de-214e9b9ebcf2"

# %%
from pprint import pprint
def get_json(url):
    print("url is:\n",url)
    opener = urllib.request.build_opener()
    opener.addheaders = [('Authorization', 'apikey token=' + API_KEY)]
    json_object = json.loads(opener.open(url).read())
    #pprint(json_object)
    return json_object

# %%
# Annotate using the provided text
text_to_annotate="nausea"#skin eczema"#"fever" #"high fever"
annotations = get_json(REST_URL + "/annotator?text=" + urllib.parse.quote(text_to_annotate))
pprint(annotations)
# Out:
# url is:
#  http://data.bioontology.org/annotator?text=nausea
# [{'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://purl.obolibrary.org/obo/ogms/OMRE_0000038',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/AERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2Fogms%2FOMRE_0000038/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/AERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2Fogms%2FOMRE_0000038/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/AERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2Fogms%2FOMRE_0000038/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/AERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2Fogms%2FOMRE_0000038/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/AERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2Fogms%2FOMRE_0000038/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/AERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2Fogms%2FOMRE_0000038/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/AERO',
#                                'parents': 'https://data.bioontology.org/ontologies/AERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2Fogms%2FOMRE_0000038/parents',
#                                'self': 'https://data.bioontology.org/ontologies/AERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2Fogms%2FOMRE_0000038',
#                                'tree': 'https://data.bioontology.org/ontologies/AERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2Fogms%2FOMRE_0000038/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/AERO?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2Fogms%2FOMRE_0000038'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://purl.bioontology.org/ontology/MEDDRA/10028813',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/MEDDRA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10028813/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/MEDDRA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10028813/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/MEDDRA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10028813/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/MEDDRA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10028813/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/MEDDRA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10028813/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/MEDDRA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10028813/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/MEDDRA',
#                                'parents': 'https://data.bioontology.org/ontologies/MEDDRA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10028813/parents',
#                                'self': 'https://data.bioontology.org/ontologies/MEDDRA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10028813',
#                                'tree': 'https://data.bioontology.org/ontologies/MEDDRA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10028813/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/MEDDRA?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMEDDRA%2F10028813'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://phenomebrowser.net/ontologies/mesh/mesh.owl#C23.888.821.712',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23C23.888.821.712/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23C23.888.821.712/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23C23.888.821.712/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23C23.888.821.712/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23C23.888.821.712/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23C23.888.821.712/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/RH-MESH',
#                                'parents': 'https://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23C23.888.821.712/parents',
#                                'self': 'https://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23C23.888.821.712',
#                                'tree': 'https://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23C23.888.821.712/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/RH-MESH?p=classes&conceptid=http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23C23.888.821.712'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://www.tcmkg.com/ISPO/ISPO_00000954',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/ISPO/classes/http%3A%2F%2Fwww.tcmkg.com%2FISPO%2FISPO_00000954/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/ISPO/classes/http%3A%2F%2Fwww.tcmkg.com%2FISPO%2FISPO_00000954/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/ISPO/classes/http%3A%2F%2Fwww.tcmkg.com%2FISPO%2FISPO_00000954/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/ISPO/classes/http%3A%2F%2Fwww.tcmkg.com%2FISPO%2FISPO_00000954/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/ISPO/classes/http%3A%2F%2Fwww.tcmkg.com%2FISPO%2FISPO_00000954/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/ISPO/classes/http%3A%2F%2Fwww.tcmkg.com%2FISPO%2FISPO_00000954/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/ISPO',
#                                'parents': 'https://data.bioontology.org/ontologies/ISPO/classes/http%3A%2F%2Fwww.tcmkg.com%2FISPO%2FISPO_00000954/parents',
#                                'self': 'https://data.bioontology.org/ontologies/ISPO/classes/http%3A%2F%2Fwww.tcmkg.com%2FISPO%2FISPO_00000954',
#                                'tree': 'https://data.bioontology.org/ontologies/ISPO/classes/http%3A%2F%2Fwww.tcmkg.com%2FISPO%2FISPO_00000954/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/ISPO?p=classes&conceptid=http%3A%2F%2Fwww.tcmkg.com%2FISPO%2FISPO_00000954'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://www.mskcc.org/ontologies/2013/03/sae.owl#Nausea',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/SSE/classes/http%3A%2F%2Fwww.mskcc.org%2Fontologies%2F2013%2F03%2Fsae.owl%23Nausea/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/SSE/classes/http%3A%2F%2Fwww.mskcc.org%2Fontologies%2F2013%2F03%2Fsae.owl%23Nausea/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/SSE/classes/http%3A%2F%2Fwww.mskcc.org%2Fontologies%2F2013%2F03%2Fsae.owl%23Nausea/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/SSE/classes/http%3A%2F%2Fwww.mskcc.org%2Fontologies%2F2013%2F03%2Fsae.owl%23Nausea/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/SSE/classes/http%3A%2F%2Fwww.mskcc.org%2Fontologies%2F2013%2F03%2Fsae.owl%23Nausea/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/SSE/classes/http%3A%2F%2Fwww.mskcc.org%2Fontologies%2F2013%2F03%2Fsae.owl%23Nausea/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/SSE',
#                                'parents': 'https://data.bioontology.org/ontologies/SSE/classes/http%3A%2F%2Fwww.mskcc.org%2Fontologies%2F2013%2F03%2Fsae.owl%23Nausea/parents',
#                                'self': 'https://data.bioontology.org/ontologies/SSE/classes/http%3A%2F%2Fwww.mskcc.org%2Fontologies%2F2013%2F03%2Fsae.owl%23Nausea',
#                                'tree': 'https://data.bioontology.org/ontologies/SSE/classes/http%3A%2F%2Fwww.mskcc.org%2Fontologies%2F2013%2F03%2Fsae.owl%23Nausea/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/SSE?p=classes&conceptid=http%3A%2F%2Fwww.mskcc.org%2Fontologies%2F2013%2F03%2Fsae.owl%23Nausea'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://purl.obolibrary.org/obo/NCIT_C3258',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/BERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FNCIT_C3258/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/BERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FNCIT_C3258/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/BERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FNCIT_C3258/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/BERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FNCIT_C3258/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/BERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FNCIT_C3258/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/BERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FNCIT_C3258/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/BERO',
#                                'parents': 'https://data.bioontology.org/ontologies/BERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FNCIT_C3258/parents',
#                                'self': 'https://data.bioontology.org/ontologies/BERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FNCIT_C3258',
#                                'tree': 'https://data.bioontology.org/ontologies/BERO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FNCIT_C3258/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/BERO?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FNCIT_C3258'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C141559',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C141559/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C141559/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C141559/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C141559/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C141559/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C141559/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/NCIT',
#                                'parents': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C141559/parents',
#                                'self': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C141559',
#                                'tree': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C141559/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/NCIT?p=classes&conceptid=http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C141559'}},
#   'annotations': [{'from': 1, 'matchType': 'SYN', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C3258',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C3258/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C3258/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C3258/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C3258/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C3258/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C3258/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/NCIT',
#                                'parents': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C3258/parents',
#                                'self': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C3258',
#                                'tree': 'https://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C3258/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/NCIT?p=classes&conceptid=http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C3258'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://bioportal/bioontology.org/ontologies/HIVO0004#OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/HIVO004/classes/http%3A%2F%2Fbioportal%2Fbioontology.org%2Fontologies%2FHIVO0004%23OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/HIVO004/classes/http%3A%2F%2Fbioportal%2Fbioontology.org%2Fontologies%2FHIVO0004%23OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/HIVO004/classes/http%3A%2F%2Fbioportal%2Fbioontology.org%2Fontologies%2FHIVO0004%23OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/HIVO004/classes/http%3A%2F%2Fbioportal%2Fbioontology.org%2Fontologies%2FHIVO0004%23OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/HIVO004/classes/http%3A%2F%2Fbioportal%2Fbioontology.org%2Fontologies%2FHIVO0004%23OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/HIVO004/classes/http%3A%2F%2Fbioportal%2Fbioontology.org%2Fontologies%2FHIVO0004%23OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/HIVO004',
#                                'parents': 'https://data.bioontology.org/ontologies/HIVO004/classes/http%3A%2F%2Fbioportal%2Fbioontology.org%2Fontologies%2FHIVO0004%23OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64/parents',
#                                'self': 'https://data.bioontology.org/ontologies/HIVO004/classes/http%3A%2F%2Fbioportal%2Fbioontology.org%2Fontologies%2FHIVO0004%23OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64',
#                                'tree': 'https://data.bioontology.org/ontologies/HIVO004/classes/http%3A%2F%2Fbioportal%2Fbioontology.org%2Fontologies%2FHIVO0004%23OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/HIVO004?p=classes&conceptid=http%3A%2F%2Fbioportal%2Fbioontology.org%2Fontologies%2FHIVO0004%23OWLClass_61875009_e9eb_42d6_b362_32f282fdfd64'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://www.limics.fr/ontologies/ontoparonmed#Nausee',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/ONTOPARON/classes/http%3A%2F%2Fwww.limics.fr%2Fontologies%2Fontoparonmed%23Nausee/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/ONTOPARON/classes/http%3A%2F%2Fwww.limics.fr%2Fontologies%2Fontoparonmed%23Nausee/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/ONTOPARON/classes/http%3A%2F%2Fwww.limics.fr%2Fontologies%2Fontoparonmed%23Nausee/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/ONTOPARON/classes/http%3A%2F%2Fwww.limics.fr%2Fontologies%2Fontoparonmed%23Nausee/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/ONTOPARON/classes/http%3A%2F%2Fwww.limics.fr%2Fontologies%2Fontoparonmed%23Nausee/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/ONTOPARON/classes/http%3A%2F%2Fwww.limics.fr%2Fontologies%2Fontoparonmed%23Nausee/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/ONTOPARON',
#                                'parents': 'https://data.bioontology.org/ontologies/ONTOPARON/classes/http%3A%2F%2Fwww.limics.fr%2Fontologies%2Fontoparonmed%23Nausee/parents',
#                                'self': 'https://data.bioontology.org/ontologies/ONTOPARON/classes/http%3A%2F%2Fwww.limics.fr%2Fontologies%2Fontoparonmed%23Nausee',
#                                'tree': 'https://data.bioontology.org/ontologies/ONTOPARON/classes/http%3A%2F%2Fwww.limics.fr%2Fontologies%2Fontoparonmed%23Nausee/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/ONTOPARON?p=classes&conceptid=http%3A%2F%2Fwww.limics.fr%2Fontologies%2Fontoparonmed%23Nausee'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://purl.bioontology.org/ontology/RCD/X75qw',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX75qw/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX75qw/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX75qw/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX75qw/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX75qw/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX75qw/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/RCD',
#                                'parents': 'https://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX75qw/parents',
#                                'self': 'https://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX75qw',
#                                'tree': 'https://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX75qw/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/RCD?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX75qw'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://mental-ontology.com/mental_health_bfo.owl#Nausea',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/MHMO/classes/http%3A%2F%2Fmental-ontology.com%2Fmental_health_bfo.owl%23Nausea/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/MHMO/classes/http%3A%2F%2Fmental-ontology.com%2Fmental_health_bfo.owl%23Nausea/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/MHMO/classes/http%3A%2F%2Fmental-ontology.com%2Fmental_health_bfo.owl%23Nausea/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/MHMO/classes/http%3A%2F%2Fmental-ontology.com%2Fmental_health_bfo.owl%23Nausea/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/MHMO/classes/http%3A%2F%2Fmental-ontology.com%2Fmental_health_bfo.owl%23Nausea/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/MHMO/classes/http%3A%2F%2Fmental-ontology.com%2Fmental_health_bfo.owl%23Nausea/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/MHMO',
#                                'parents': 'https://data.bioontology.org/ontologies/MHMO/classes/http%3A%2F%2Fmental-ontology.com%2Fmental_health_bfo.owl%23Nausea/parents',
#                                'self': 'https://data.bioontology.org/ontologies/MHMO/classes/http%3A%2F%2Fmental-ontology.com%2Fmental_health_bfo.owl%23Nausea',
#                                'tree': 'https://data.bioontology.org/ontologies/MHMO/classes/http%3A%2F%2Fmental-ontology.com%2Fmental_health_bfo.owl%23Nausea/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/MHMO?p=classes&conceptid=http%3A%2F%2Fmental-ontology.com%2Fmental_health_bfo.owl%23Nausea'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://purl.obolibrary.org/obo/CCTO_000333',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/CCTOO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCCTO_000333/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/CCTOO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCCTO_000333/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/CCTOO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCCTO_000333/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/CCTOO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCCTO_000333/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/CCTOO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCCTO_000333/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/CCTOO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCCTO_000333/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/CCTOO',
#                                'parents': 'https://data.bioontology.org/ontologies/CCTOO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCCTO_000333/parents',
#                                'self': 'https://data.bioontology.org/ontologies/CCTOO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCCTO_000333',
#                                'tree': 'https://data.bioontology.org/ontologies/CCTOO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCCTO_000333/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/CCTOO?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCCTO_000333'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://sbmi.uth.tmc.edu/ontology/ochv#8525',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%238525/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%238525/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%238525/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%238525/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%238525/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%238525/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/OCHV',
#                                'parents': 'https://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%238525/parents',
#                                'self': 'https://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%238525',
#                                'tree': 'https://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%238525/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/OCHV?p=classes&conceptid=http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%238525'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://www.semanticweb.org/admin/ontologies/2022/7/MIO:00119',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/MIO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fadmin%2Fontologies%2F2022%2F7%2FMIO%3A00119/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/MIO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fadmin%2Fontologies%2F2022%2F7%2FMIO%3A00119/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/MIO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fadmin%2Fontologies%2F2022%2F7%2FMIO%3A00119/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/MIO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fadmin%2Fontologies%2F2022%2F7%2FMIO%3A00119/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/MIO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fadmin%2Fontologies%2F2022%2F7%2FMIO%3A00119/mappings',
# ...
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/ONTOKBCF/classes/http%3A%2F%2Fwww.owl-ontologies.com%2Fassert.owl%23Nausea/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/ONTOKBCF/classes/http%3A%2F%2Fwww.owl-ontologies.com%2Fassert.owl%23Nausea/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/ONTOKBCF/classes/http%3A%2F%2Fwww.owl-ontologies.com%2Fassert.owl%23Nausea/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/ONTOKBCF/classes/http%3A%2F%2Fwww.owl-ontologies.com%2Fassert.owl%23Nausea/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/ONTOKBCF/classes/http%3A%2F%2Fwww.owl-ontologies.com%2Fassert.owl%23Nausea/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/ONTOKBCF/classes/http%3A%2F%2Fwww.owl-ontologies.com%2Fassert.owl%23Nausea/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/ONTOKBCF',
#                                'parents': 'https://data.bioontology.org/ontologies/ONTOKBCF/classes/http%3A%2F%2Fwww.owl-ontologies.com%2Fassert.owl%23Nausea/parents',
#                                'self': 'https://data.bioontology.org/ontologies/ONTOKBCF/classes/http%3A%2F%2Fwww.owl-ontologies.com%2Fassert.owl%23Nausea',
#                                'tree': 'https://data.bioontology.org/ontologies/ONTOKBCF/classes/http%3A%2F%2Fwww.owl-ontologies.com%2Fassert.owl%23Nausea/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/ONTOKBCF?p=classes&conceptid=http%3A%2F%2Fwww.owl-ontologies.com%2Fassert.owl%23Nausea'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://www.semanticweb.org/danielhier/ontologies/2019/3/untitled-ontology-57/nausea',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/NEO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/NEO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/NEO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/NEO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/NEO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/NEO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/NEO',
#                                'parents': 'https://data.bioontology.org/ontologies/NEO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/parents',
#                                'self': 'https://data.bioontology.org/ontologies/NEO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea',
#                                'tree': 'https://data.bioontology.org/ontologies/NEO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/NEO?p=classes&conceptid=http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://www.semanticweb.org/danielhier/ontologies/2019/3/untitled-ontology-57/nausea',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/EPISEM/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/EPISEM/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/EPISEM/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/EPISEM/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/EPISEM/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/EPISEM/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/EPISEM',
#                                'parents': 'https://data.bioontology.org/ontologies/EPISEM/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/parents',
#                                'self': 'https://data.bioontology.org/ontologies/EPISEM/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea',
#                                'tree': 'https://data.bioontology.org/ontologies/EPISEM/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/EPISEM?p=classes&conceptid=http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://www.semanticweb.org/danielhier/ontologies/2019/3/untitled-ontology-57/nausea',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/MEPO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/MEPO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/MEPO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/MEPO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/MEPO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/MEPO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/MEPO',
#                                'parents': 'https://data.bioontology.org/ontologies/MEPO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/parents',
#                                'self': 'https://data.bioontology.org/ontologies/MEPO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea',
#                                'tree': 'https://data.bioontology.org/ontologies/MEPO/classes/http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/MEPO?p=classes&conceptid=http%3A%2F%2Fwww.semanticweb.org%2Fdanielhier%2Fontologies%2F2019%2F3%2Funtitled-ontology-57%2Fnausea'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []},
#  {'annotatedClass': {'@context': {'@vocab': 'http://data.bioontology.org/metadata/'},
#                      '@id': 'http://purl.jp/bio/11/csso/CSSO_000168',
#                      '@type': 'http://www.w3.org/2002/07/owl#Class',
#                      'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                                             'children': 'http://www.w3.org/2002/07/owl#Class',
#                                             'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                                             'instances': 'http://data.bioontology.org/metadata/Instance',
#                                             'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                                             'notes': 'http://data.bioontology.org/metadata/Note',
#                                             'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                                             'parents': 'http://www.w3.org/2002/07/owl#Class',
#                                             'self': 'http://www.w3.org/2002/07/owl#Class',
#                                             'tree': 'http://www.w3.org/2002/07/owl#Class',
#                                             'ui': 'http://www.w3.org/2002/07/owl#Class'},
#                                'ancestors': 'https://data.bioontology.org/ontologies/CSSO/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F11%2Fcsso%2FCSSO_000168/ancestors',
#                                'children': 'https://data.bioontology.org/ontologies/CSSO/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F11%2Fcsso%2FCSSO_000168/children',
#                                'descendants': 'https://data.bioontology.org/ontologies/CSSO/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F11%2Fcsso%2FCSSO_000168/descendants',
#                                'instances': 'https://data.bioontology.org/ontologies/CSSO/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F11%2Fcsso%2FCSSO_000168/instances',
#                                'mappings': 'https://data.bioontology.org/ontologies/CSSO/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F11%2Fcsso%2FCSSO_000168/mappings',
#                                'notes': 'https://data.bioontology.org/ontologies/CSSO/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F11%2Fcsso%2FCSSO_000168/notes',
#                                'ontology': 'https://data.bioontology.org/ontologies/CSSO',
#                                'parents': 'https://data.bioontology.org/ontologies/CSSO/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F11%2Fcsso%2FCSSO_000168/parents',
#                                'self': 'https://data.bioontology.org/ontologies/CSSO/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F11%2Fcsso%2FCSSO_000168',
#                                'tree': 'https://data.bioontology.org/ontologies/CSSO/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F11%2Fcsso%2FCSSO_000168/tree',
#                                'ui': 'http://bioportal.bioontology.org/ontologies/CSSO?p=classes&conceptid=http%3A%2F%2Fpurl.jp%2Fbio%2F11%2Fcsso%2FCSSO_000168'}},
#   'annotations': [{'from': 1, 'matchType': 'PREF', 'text': 'NAUSEA', 'to': 6}],
#   'hierarchy': [],
#   'mappings': []}]

# %%
for result in annotations:
        for annotation in result["annotations"]:
            print("\tfrom: " + str(annotation["from"]))
            print("\tto: " + str(annotation["to"]))
            print("\tmatch type: " + annotation["matchType"])

        if result["hierarchy"]:
            print("\n\tHierarchy annotations")
            for annotation in result["hierarchy"]:
                try:
                    class_details = get_json(annotation["annotatedClass"]["links"]["self"])
                except urllib.error.HTTPError:
                    print(f"Error retrieving {annotation['annotatedClass']['@id']}")
                    continue
                pref_label = class_details["prefLabel"] or "no label"

                print("\t\tClass details")
                print("\t\t\tid: " + class_details["@id"])
                print("\t\t\tprefLabel: " + str(class_details["prefLabel"]))
                print("\t\t\tontology: " + class_details["links"]["ontology"])
                print("\t\t\tdistance from originally annotated class: " + str(annotation["distance"]))

                if str(annotation["distance"])=="1":
                  print("annotation distance is 1")
                  pass
                elif str(annotation["distance"])=="2":
                  print("annotation distance is 2")
                  pass
                elif str(annotation["distance"])=="3":
                  print("annotation distance is 3")
                  pass
                elif str(annotation["distance"])=="4":
                  print("annotation distance is 4")
                  pass
                elif str(annotation["distance"])=="5":
                  print("annotation distance is 5")
                  pass
        else:
          print("\n\tNO Hierarchy annotations")
# Out:
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: SYN
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
# 	from: 1
# 	to: 6
# 	match type: PREF
#
# 	NO Hierarchy annotations
